# %% [markdown]
# # Build Your Own Hugging Face Container

# %% [markdown]
# For most of your use cases, you may not need to create a container to bring your own code to Amazon SageMaker. When you are using a commonly used ML framework such as [TensorFlow](https://github.com/aws/sagemaker-tensorflow-container), [MXNet](https://github.com/aws/sagemaker-mxnet-container), [PyTorch](https://github.com/aws/sagemaker-pytorch-container) or [Chainer](https://github.com/aws/sagemaker-chainer-container) that has direct support in SageMaker to train and deploy a ML model, you can simply supply the Python code that implements your algorithm using the SDK entry points for that framework.
#
# Even if there is direct SDK support for your environment or framework, you may want to add additional functionality or configure your container environment differently while utilizing our container to use on SageMaker.
#
# **Some of the reasons to extend a SageMaker deep learning framework container are:**
# 1. Install additional dependencies. (E.g. I want to install a specific Python library, that the current SageMaker containers don't install.)
# 2. Configure your environment. (E.g. I want to add an environment variable to my container.)
#
# **Although it is possible to extend any of our framework containers as a parent image, the example this notebook covers is currently only intended to work with our PyTorch (0.4.0+) and Chainer (4.1.0+) containers.**
#
# This walkthrough shows that it is quite straightforward to extend one of our containers to build your own custom container for PyTorch or Chainer.
#
# ## Permissions
#
# Running this notebook requires permissions in addition to the normal `SageMakerFullAccess` permissions. This is because it creates new repositories in Amazon ECR. The easiest way to add these permissions is simply to add the managed policy `AmazonEC2ContainerRegistryFullAccess` to the role that you used to start your notebook instance. There's no need to restart your notebook instance when you do this, the new permissions will be available immediately.
#
# ## The example
#
# In this example we show how to package a PyTorch container, extending the SageMaker PyTorch container, with a Python example which works with the Hugging Face dataset. By extending the SageMaker PyTorch container we can utilize the existing training and hosting solution made to work on SageMaker. By comparison, if one were to build their own custom framework container from scratch, they would need to implement a training and hosting solution in order to use SageMaker. Here is an example showing [how to create a SageMaker TensorFlow container from scratch](https://github.com/awslabs/amazon-sagemaker-examples/blob/master/advanced_functionality/tensorflow_bring_your_own/tensorflow_bring_your_own.ipynb).
#
# In this example, we use a single image to support training and hosting. This simplifies the procedure because we only need to manage one image for both tasks. Sometimes you may want separate images for training and hosting because they have different requirements. In this case, separate the parts discussed below into separate Dockerfiles and build two images. Choosing whether to use a single image or two images is a matter of what is most convenient for you to develop and manage.
#
# If you're only using Amazon SageMaker for training or hosting, but not both, only the functionality used needs to be built into your container.

# %% [markdown]
# ##Packaging and Uploading your Algorithm for use with Amazon SageMaker
#
# ### An overview of Docker
#
# If you're familiar with Docker already, you can skip ahead to the next section.
#
# For many data scientists, Docker containers are a new technology. But they are not difficult and can significantly simplify the deployment of your software packages.
#
# Docker provides a simple way to package arbitrary code into an _image_ that is totally self-contained. Once you have an image, you can use Docker to run a _container_ based on that image. Running a container is just like running a program on the machine except that the container creates a fully self-contained environment for the program to run. Containers are isolated from each other and from the host environment, so the way your program is set up is the way it runs, no matter where you run it.
#
# Docker is more powerful than environment managers like conda or virtualenv because (a) it is completely language independent and (b) it comprises your whole operating environment, including startup commands, and environment variable.
#
# A Docker container is like a virtual machine, but it is much lighter weight. For example, a program running in a container can start in less than a second and many containers can run simultaneously on the same physical or virtual machine instance.
#
# Docker uses a simple file called a `Dockerfile` to specify how the image is assembled. An example is provided below. You can build your Docker images based on Docker images built by yourself or by others, which can simplify things quite a bit.
#
# Docker has become very popular in programming and devops communities due to its flexibility and its well-defined specification of how code can be run in its containers. It is the underpinning of many services built in the past few years, such as [Amazon ECS].
#
# Amazon SageMaker uses Docker to allow users to train and deploy arbitrary algorithms.
#
# In Amazon SageMaker, Docker containers are invoked in a one way for training and another, slightly different, way for hosting. The following sections outline how to build containers for the SageMaker environment.
#
# Some helpful links:
#
# * [Docker home page](http://www.docker.com)
# * [Getting started with Docker](https://docs.docker.com/get-started/)
# * [Dockerfile reference](https://docs.docker.com/engine/reference/builder/)
# * [`docker run` reference](https://docs.docker.com/engine/reference/run/)
#
# [Amazon ECS]: https://aws.amazon.com/ecs/
#
# ### How Amazon SageMaker runs your Docker container
#
# Because you can run the same image in training or hosting, Amazon SageMaker runs your container with the argument `train` or `serve`. How your container processes this argument depends on the container. All SageMaker deep learning framework containers already cover this requirement and will trigger your defined training algorithm and inference code.
#
# * If you specify a program as an `ENTRYPOINT` in the Dockerfile, that program will be run at startup and its first argument will be `train` or `serve`. The program can then look at that argument and decide what to do. The original `ENTRYPOINT` specified within the SageMaker PyTorch is [here](https://github.com/aws/deep-learning-containers/blob/master/pytorch/training/docker/1.5.1/py3/Dockerfile.cpu#L123).
#
# #### Running your container during training
#
# Currently, our SageMaker PyTorch container utilizes [console_scripts](http://python-packaging.readthedocs.io/en/latest/command-line-scripts.html#the-console-scripts-entry-point) to make use of the `train` command issued at training time. The line that gets invoked during `train` is defined within the setup.py file inside [SageMaker Containers](https://github.com/aws/sagemaker-containers/blob/master/setup.py#L48), our common SageMaker deep learning container framework. When this command is run, it will invoke the [trainer class](https://github.com/aws/sagemaker-containers/blob/master/src/sagemaker_containers/cli/train.py) to run, which will finally invoke our [PyTorch container code](https://github.com/aws/sagemaker-pytorch-container/blob/master/src/sagemaker_pytorch_container/training.py) to run your Python file.
#
# A number of files are laid out for your use, under the `/opt/ml` directory:
#
#     /opt/ml
#     |-- input
#     |   |-- config
#     |   |   |-- hyperparameters.json
#     |   |   `-- resourceConfig.json
#     |   `-- data
#     |       `-- <channel_name>
#     |           `-- <input data>
#     |-- model
#     |   `-- <model files>
#     `-- output
#         `-- failure
#
# ##### The input
#
# * `/opt/ml/input/config` contains information to control how your program runs. `hyperparameters.json` is a JSON-formatted dictionary of hyperparameter names to values. These values are always strings, so you may need to convert them. `resourceConfig.json` is a JSON-formatted file that describes the network layout used for distributed training.
# * `/opt/ml/input/data/<channel_name>/` (for File mode) contains the input data for that channel. The channels are created based on the call to CreateTrainingJob but it's generally important that channels match algorithm expectations. The files for each channel are copied from S3 to this directory, preserving the tree structure indicated by the S3 key structure.
# * `/opt/ml/input/data/<channel_name>_<epoch_number>` (for Pipe mode) is the pipe for a given epoch. Epochs start at zero and go up by one each time you read them. There is no limit to the number of epochs that you can run, but you must close each pipe before reading the next epoch.
#
# ##### The output
#
# * `/opt/ml/model/` is the directory where you write the model that your algorithm generates. Your model can be in any format that you want. It can be a single file or a whole directory tree. SageMaker packages any files in this directory into a compressed tar archive file. This file is made available at the S3 location returned in the `DescribeTrainingJob` result.
# * `/opt/ml/output` is a directory where the algorithm can write a file `failure` that describes why the job failed. The contents of this file are returned in the `FailureReason` field of the `DescribeTrainingJob` result. For jobs that succeed, there is no reason to write this file as it is ignored.
#
# #### Running your container during hosting
#
# Hosting has a very different model than training because hosting is reponding to inference requests that come in via HTTP. Currently, the SageMaker PyTorch containers [uses](https://github.com/aws/sagemaker-pytorch-container/blob/master/src/sagemaker_pytorch_container/serving.py#L103) our [recommended Python serving stack](https://github.com/aws/sagemaker-containers/blob/master/src/sagemaker_containers/_server.py#L44) to provide robust and scalable serving of inference requests:
#
# ![Request serving stack](stack.png)
#
# Amazon SageMaker uses two URLs in the container:
#
# * `/ping` receives `GET` requests from the infrastructure. Your program returns 200 if the container is up and accepting requests.
# * `/invocations` is the endpoint that receives client inference `POST` requests. The format of the request and the response is up to the algorithm. If the client supplied `ContentType` and `Accept` headers, these are passed in as well.
#
# The container has the model files in the same place that they were written to during training:
#
#     /opt/ml
#     `-- model
#         `-- <model files>

# %% [markdown]
# ## The Dockerfile
#
# The Dockerfile describes the image that we want to build. You can think of it as describing the complete operating system installation of the system that you want to run. A Docker container running is quite a bit lighter than a full operating system, however, because it takes advantage of Linux on the host machine for the basic operations.
#
# We start from the SageMaker PyTorch image as the base. The base image is an ECR image, so it will have the following pattern.
# * {account}.dkr.ecr.{region}.amazonaws.com/sagemaker-{framework}:{framework_version}-{processor_type}-{python_version}
#
# Here is an explanation of each field.
# 1. account - AWS account ID the ECR image belongs to. Our public deep learning framework images are all under the 520713654638 account.
# 2. region - The region the ECR image belongs to. [Available regions](https://aws.amazon.com/about-aws/global-infrastructure/regional-product-services/).
# 3. framework - The deep learning framework.
# 4. framework_version - The version of the deep learning framework.
# 5. processor_type - CPU or GPU.
# 6. python_version - The supported version of Python.
#
# So the SageMaker PyTorch ECR image would be:
# 520713654638.dkr.ecr.us-west-2.amazonaws.com/sagemaker-pytorch:0.4.0-cpu-py3
#
# Information on supported frameworks and versions can be found in this [README](https://github.com/aws/sagemaker-python-sdk).
#
# Next, we add the code that implements our specific algorithm to the container and set up the right environment for it to run under.
#
# **DISCLAIMER: As of now, the support for the two environment variables below are only supported for the SageMaker Chainer (4.1.0+) and PyTorch (0.4.0+) containers.**
#
# Finally, we need to specify two environment variables.
# 1. SAGEMAKER_SUBMIT_DIRECTORY - the directory within the container containing our Python script for training and inference.
# 2. SAGEMAKER_PROGRAM - the Python script that should be invoked for training and inference.
#
# Let's look at the Dockerfile for this example.

# %%
# !cat scripts/Dockerfile.gpu
# Out:
# # https://github.com/aws/deep-learning-containers/blob/master/available_images.md
# # refer to the above page to pull latest Pytorch image
#
# # docker image region us-west-2
# #FROM 763104351884.dkr.ecr.us-east-1.amazonaws.com/pytorch-training:1.9.0-gpu-py38-cu111-ubuntu20.04
# #FROM 763104351884.dkr.ecr.us-west-2.amazonaws.com/pytorch-training:1.9.0-gpu-py38-cu111-ubuntu20.04
# FROM 763104351884.dkr.ecr.us-west-2.amazonaws.com/huggingface-pytorch-training:1.9.0-transformers4.11.0-gpu-py38-cu111-ubuntu20.04
#
# LABEL maintainer="Amazon AI"
# LABEL dlc_major_version="1"
#
# # version args
# ARG TRANSFORMERS_VERSION
# ARG DATASETS_VERSION
# ARG PYTHON=python3
#
# # install Hugging Face libraries and its dependencies
# RUN pip install --no-cache-dir \
# 	transformers[sklearn,sentencepiece]==${TRANSFORMERS_VERSION} \
# 	datasets==${DATASETS_VERSION} \
# 	# TODO: Remove upgrade statements once packages are updated in base image
# 	"Pillow>=8.3.2"
#
# RUN apt-get update \
#  # TODO: Remove upgrade statements once packages are updated in base image
#  && apt-get -y upgrade --only-upgrade systemd openssl \
#  && apt install -y git-lfs \
#  && apt-get clean \
#  && rm -rf /var/lib/apt/lists/*
#
# RUN HOME_DIR=/root \
#  && curl -o ${HOME_DIR}/oss_compliance.zip https://aws-dlinfra-utilities.s3.amazonaws.com/oss_compliance.zip \
#  && unzip ${HOME_DIR}/oss_compliance.zip -d ${HOME_DIR}/ \
#  && cp ${HOME_DIR}/oss_compliance/test/testOSSCompliance /usr/local/bin/testOSSCompliance \
#  && chmod +x /usr/local/bin/testOSSCompliance \
#  && chmod +x ${HOME_DIR}/oss_compliance/generate_oss_compliance.sh \
#  && ${HOME_DIR}/oss_compliance/generate_oss_compliance.sh ${HOME_DIR} ${PYTHON} \
#  && rm -rf ${HOME_DIR}/oss_compliance*
#
# # When installing in editable mode, `transformers` is not recognized as a package.
# # this line must be added in order for python to be aware of transformers.
# #RUN cd transformers && python3 setup.py develop
#
# ENV PATH="/opt/ml/code:${PATH}"
#
# ## this environment variable is used by the SageMaker PyTorch container to determine our user code directory.
# ENV SAGEMAKER_SUBMIT_DIRECTORY /opt/ml/code
#
# ## /opt/ml and all subdirectories are utilized by SageMaker, use the /code subdirectory to store your user code.
# COPY trainer_qa.py /opt/ml/code/trainer_qa.py
# COPY run_qa.py /opt/ml/code/train.py
# COPY utils_qa.py /opt/ml/code/utils_qa.py
#
# ## Define script entrypoint
# ENV SAGEMAKER_PROGRAM /opt/ml/code/train.py

# %% [markdown]
# !cat scripts/environment.yml

# %% [markdown]
# ## Building and registering the container
#
# The following shell code shows how to build the container image using `docker build` and push the container image to ECR using `docker push`. This code is also available as the shell script `container/build-and-push.sh`, which you can run as `build-and-push.sh pytorch-extending-our-containers-example` to build the image `pytorch-extending-our-containers-example`.
#
# This code looks for an ECR repository in the account you're using and the current default region (if you're using a SageMaker notebook instance, this is the region where the notebook instance was created). If the repository doesn't exist, the script will create it. In addition, since we are using the SageMaker PyTorch image as the base, we will need to retrieve ECR credentials to pull this public image.

# %%
# %%sh
#
# # The name of our algorithm
# algorithm_name=torch-hf-gpu-100
# cd scripts
#
# account=$(aws sts get-caller-identity --query Account --output text)
# #ecr_image = '{}.dkr.ecr.{}.amazonaws.com/{}:latest'.format(account[0], region, algorithm_name)
# # Get the region defined in the current configuration (default to us-west-2 if none defined)
# region=$(aws configure get region)
# region=${region:-us-west-2}
#
# fullname="${account}.dkr.ecr.${region}.amazonaws.com/${algorithm_name}:latest"
#
# # If the repository doesn't exist in ECR, create it.
# aws ecr describe-repositories --repository-names "${algorithm_name}" > /dev/null 2>&1
#
# if [ $? -ne 0 ]
# then
#     aws ecr create-repository --repository-name "${algorithm_name}" > /dev/null
# fi
#
# # Get the login command from ECR and execute it directly
# #$(aws ecr get-login --region ${region} --no-include-email)
#
# # Get the login command from ECR in order to pull down the SageMaker PyTorch image
# #$(aws ecr get-login --registry-ids 520713654638 --region ${region} --no-include-email)
# aws ecr get-login-password --region ${region}| docker login --username AWS --password-stdin ${fullname}
# # Get the login command from ECR and execute it directly for the container image account
# aws ecr get-login-password --region "${region}" | docker login --username AWS --password-stdin 763104351884.dkr.ecr."${region}".amazonaws.com
#
#
# # Build the docker image locally with the image name and then push it to ECR
# # with the full name.
#
# docker build -t ${algorithm_name} . -f Dockerfile.gpu --build-arg REGION=${region} --build-arg TRANSFORMERS_VERSION=4.19.2 --build-arg DATASETS_VERSION=2.2
# docker tag ${algorithm_name} ${fullname}
#
# docker push ${fullname}
# Out:
# Login Succeeded
# Login Succeeded
# Sending build context to Docker daemon  230.9kB
# Step 1/15 : FROM 763104351884.dkr.ecr.us-west-2.amazonaws.com/huggingface-pytorch-training:1.9.0-transformers4.11.0-gpu-py38-cu111-ubuntu20.04
#  ---> efba7203afb3
# Step 2/15 : LABEL maintainer="Amazon AI"
#  ---> Using cache
#  ---> b58f737d13ee
# Step 3/15 : LABEL dlc_major_version="1"
#  ---> Using cache
#  ---> 356d745e3b7b
# Step 4/15 : ARG TRANSFORMERS_VERSION
#  ---> Using cache
#  ---> 89b851da7086
# Step 5/15 : ARG DATASETS_VERSION
#  ---> Using cache
#  ---> 1872202c769f
# Step 6/15 : ARG PYTHON=python3
#  ---> Using cache
#  ---> c98c4cb93cdc
# Step 7/15 : RUN pip install --no-cache-dir 	transformers[sklearn,sentencepiece]==${TRANSFORMERS_VERSION} 	datasets==${DATASETS_VERSION} 	"Pillow>=8.3.2"
#  ---> Using cache
#  ---> 9cb23c0ab4e3
# Step 8/15 : RUN apt-get update  && apt-get -y upgrade --only-upgrade systemd openssl  && apt install -y git-lfs  && apt-get clean  && rm -rf /var/lib/apt/lists/*
#  ---> Using cache
#  ---> 9d80aaec8e05
# Step 9/15 : RUN HOME_DIR=/root  && curl -o ${HOME_DIR}/oss_compliance.zip https://aws-dlinfra-utilities.s3.amazonaws.com/oss_compliance.zip  && unzip ${HOME_DIR}/oss_compliance.zip -d ${HOME_DIR}/  && cp ${HOME_DIR}/oss_compliance/test/testOSSCompliance /usr/local/bin/testOSSCompliance  && chmod +x /usr/local/bin/testOSSCompliance  && chmod +x ${HOME_DIR}/oss_compliance/generate_oss_compliance.sh  && ${HOME_DIR}/oss_compliance/generate_oss_compliance.sh ${HOME_DIR} ${PYTHON}  && rm -rf ${HOME_DIR}/oss_compliance*
#  ---> Using cache
#  ---> acce6f2ff716
# Step 10/15 : ENV PATH="/opt/ml/code:${PATH}"
#  ---> Using cache
#  ---> 006a29b4fe7d
# Step 11/15 : ENV SAGEMAKER_SUBMIT_DIRECTORY /opt/ml/code
#  ---> Using cache
#  ---> a7661d741ba0
# Step 12/15 : COPY trainer_qa.py /opt/ml/code/trainer_qa.py
#  ---> d974c468113b
# Step 13/15 : COPY run_qa.py /opt/ml/code/train.py
#  ---> 8cfc74ad1a51
# Step 14/15 : COPY utils_qa.py /opt/ml/code/utils_qa.py
#  ---> e0abf3ae2c69
# Step 15/15 : ENV SAGEMAKER_PROGRAM /opt/ml/code/train.py
#  ---> Running in ced5e713b4eb
# Removing intermediate container ced5e713b4eb
#  ---> 7468c25c4b5a
# [Warning] One or more build-args [REGION] were not consumed
# Successfully built 7468c25c4b5a
# Successfully tagged torch-hf-gpu-100:latest
# The push refers to repository [976939723775.dkr.ecr.us-west-2.amazonaws.com/torch-hf-gpu-100]
# 426a516001a1: Preparing
# 42a3318159b1: Preparing
# 4e8857d8e0d0: Preparing
# cb3ab6d25422: Preparing
# 6e9c36f85a01: Preparing
# 35270a163ab8: Preparing
# c82e992a9242: Preparing
# 10b81688a422: Preparing
# 892611c6e1d7: Preparing
# 6899eff284e2: Preparing
# ff9e3ce5b649: Preparing
# a09498cafb12: Preparing
# 477b62f83597: Preparing
# 558aad705eaa: Preparing
# 087f21989a4d: Preparing
# 4515911b1319: Preparing
# a0386e034409: Preparing
# ada1a90e156a: Preparing
# c78034604f80: Preparing
# 482cc18c85c8: Preparing
# 815ba42af0da: Preparing
# e64d8899579f: Preparing
# 416ba6e8260e: Preparing
# e553f024dd9c: Preparing
# 9eb6a5dc3e4e: Preparing
# 4067cab1de8d: Preparing
# a0d303de899c: Preparing
# d387cffa5382: Preparing
# 3ec0453fc4ef: Preparing
# 8ad307a7346b: Preparing
# fd80965c9285: Preparing
# b16a96ddd384: Preparing
# b1cccc825ec0: Preparing
# 857bf3b0f5df: Preparing
# 3706727b2a0b: Preparing
# 7a1fa2791d6b: Preparing
# 5dc27e1350e5: Preparing
# fda7955c9ce4: Preparing
# 070915bcb457: Preparing
# 4721c5a1ad3c: Preparing
# 091899f90588: Preparing
# 6899eff284e2: Waiting
# 25171e6b1484: Preparing
# 514dfbcce645: Preparing
# 9e4d92def612: Preparing
# f090ced90acc: Preparing
# a0386e034409: Waiting
# 7555a8182c42: Preparing
# 4515911b1319: Waiting
# ada1a90e156a: Waiting
# 558aad705eaa: Waiting
# a09498cafb12: Waiting
# ff9e3ce5b649: Waiting
# 477b62f83597: Waiting
# e64d8899579f: Waiting
# 087f21989a4d: Waiting
# 3706727b2a0b: Waiting
# 416ba6e8260e: Waiting
# c78034604f80: Waiting
# 091899f90588: Waiting
# 7a1fa2791d6b: Waiting
# e553f024dd9c: Waiting
# 25171e6b1484: Waiting
# 3ec0453fc4ef: Waiting
# 5dc27e1350e5: Waiting
# 482cc18c85c8: Waiting
# 9eb6a5dc3e4e: Waiting
# 514dfbcce645: Waiting
# 8ad307a7346b: Waiting
# fda7955c9ce4: Waiting
# 4067cab1de8d: Waiting
# 815ba42af0da: Waiting
# 9e4d92def612: Waiting
# fd80965c9285: Waiting
# 070915bcb457: Waiting
# f090ced90acc: Waiting
# b16a96ddd384: Waiting
# a0d303de899c: Waiting
# 4721c5a1ad3c: Waiting
# b1cccc825ec0: Waiting
# 7555a8182c42: Waiting
# 857bf3b0f5df: Waiting
# c82e992a9242: Waiting
# 35270a163ab8: Waiting
# 10b81688a422: Waiting
# 892611c6e1d7: Waiting
# 4e8857d8e0d0: Pushed
# 42a3318159b1: Pushed
# 426a516001a1: Pushed
# cb3ab6d25422: Pushed
# c82e992a9242: Pushed
# 6899eff284e2: Pushed
# ff9e3ce5b649: Pushed
# a09498cafb12: Pushed
# 477b62f83597: Pushed
# 558aad705eaa: Pushed
# 087f21989a4d: Pushed
# 892611c6e1d7: Pushed
# 4515911b1319: Pushed
# a0386e034409: Pushed
# c78034604f80: Pushed
# 482cc18c85c8: Pushed
# 35270a163ab8: Pushed
# e64d8899579f: Pushed
# 815ba42af0da: Pushed
# e553f024dd9c: Pushed
# 416ba6e8260e: Pushed
# 4067cab1de8d: Pushed
# a0d303de899c: Pushed
# 9eb6a5dc3e4e: Pushed
# 10b81688a422: Pushed
# 8ad307a7346b: Pushed
# fd80965c9285: Pushed
# b16a96ddd384: Pushed
# ada1a90e156a: Pushed
# b1cccc825ec0: Pushed
# 3706727b2a0b: Pushed
# 7a1fa2791d6b: Pushed
# 6e9c36f85a01: Pushed
# fda7955c9ce4: Pushed
# 857bf3b0f5df: Pushed
# d387cffa5382: Pushed
# 070915bcb457: Pushed
# 25171e6b1484: Pushed
# 514dfbcce645: Pushed
# 9e4d92def612: Pushed
# f090ced90acc: Pushed
# 7555a8182c42: Pushed
# 4721c5a1ad3c: Pushed
# 5dc27e1350e5: Pushed
# 3ec0453fc4ef: Pushed
# 091899f90588: Pushed
# latest: digest: sha256:2205b7eaf4c3f812d3c41ac4a024ee218268ae177f41cbe5f591e56a7dc20599 size: 9995
# WARNING! Your password will be stored unencrypted in /home/alfred/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# WARNING! Your password will be stored unencrypted in /home/alfred/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store

# %% [markdown]
# ### Training with Amazon SageMaker
# Once we have correctly pushed our container to Amazon ECR, we are ready to start training with Amazon SageMaker, which requires the ECR path to the Docker container used for training as parameter for starting a training job.
#
# SageMaker sets up a docker container for a training job where:
#
# * Environment variables are set as in SageMaker Docker Container. Environment Variables.
# * Training data is setup under /opt/ml/input/data.
# * Training script codes are setup under /opt/ml/code.
#
# /opt/ml/model and /opt/ml/output directories are setup to store training outputs.
#
# ```
# /opt/ml
# ├── input
# │   ├── config
# │   │   ├── hyperparameters.json  <--- From Estimator hyperparameter arg
# │   │   └── resourceConfig.json
# │   └── data
# │       └── <channel_name>        <--- From Estimator fit method inputs arg
# │           └── <input data>
# ├── code
# │   └── <code files>              <--- From Estimator src_dir arg
# ├── model
# │   └── <model files>             <--- Location to save the trained model artifacts
# └── output
#     └── failure                   <--- Training job failure logs
# ```
#
# SageMaker Estimator fit(inputs) method executes the training script. Estimator hyperparameters and fit method inputs are provided as its command line arguments.
#
# * The training script saves the model artifacts in the /opt/ml/model once the training is completed.
#
# * SageMaker archives the artifacts under /opt/ml/model into model.tar.gz and save it to the S3 location specified to output_path Estimator parameter.
#
# * You can set Estimator metric_definitions parameter to extract model metrics from the training logs. Then you can monitor the training progress in the SageMaker console metrics.
#
# ![SM_Diagram](https://i.stack.imgur.com/gi8bU.png)
#
#
# The Amazon SageMaker Python SDK provides framework estimators and generic estimators to train your model while orchestrating the machine learning (ML) lifecycle accessing the SageMaker features for training and the AWS infrastructures. To train a model by using the SageMaker Python SDK:
#
# 1. Prepare a training script
# 2. Create an estimator
# 3. Call the fit method of the estimator
# 4. Finally this document gives concrete steps and ideas. However still missing comprehensiv details about Environment Variables, Directory structure in the SageMaker docker container**, S3 for uploading code, placing data, S3 where the trained model is saved, etc.

# %%
import boto3
session = boto3.session.Session()
region = session.region_name

algorithm_name='torch-hf-gpu-100'
account_id = boto3.client('sts').get_caller_identity().get('Account')

container_image_uri = "{0}.dkr.ecr.{1}.amazonaws.com/{2}:latest".format(
    account_id, region, algorithm_name
)
print(container_image_uri)
# Out:
# 976939723775.dkr.ecr.us-west-2.amazonaws.com/torch-hf-gpu-100:latest

# %%
from transformers import AutoTokenizer

# tokenizer used in preprocessing
tokenizer_name = 'bert-large-uncased-whole-word-masking'
#tokenizer_name = 'roberta-large'

# download tokenizer
tokenizer = AutoTokenizer.from_pretrained(tokenizer_name)

# %%
job_name='torch-hf-gpu-2022-06-14-01'
#role = sagemaker.get_execution_role()
role = 'arn:aws:iam::976939723775:role/service-role/AmazonSageMaker-ExecutionRole-20210317T133000'

# %% [markdown]
# ### Start docker in local model

# %%
import sagemaker
import json

# JSON encode hyperparameters.
def json_encode_hyperparameters(hyperparameters):
    return {str(k): json.dumps(v) for (k, v) in hyperparameters.items()}

'''
hyperparameters_1 = json_encode_hyperparameters(
    {
        "sagemaker_program": "train.py",
        "sagemaker_submit_directory": sources,
        "hp1": "value1",
        "hp2": 300,
        "hp3": 0.001,
    }
)
'''

# hyperparameters, which are passed into the training job
hyperparameters={
    'model_name_or_path': tokenizer_name,
    'dataset_name':'squad',
    'do_train': True,
    'do_eval': True,
    'fp16': True,
    'per_device_train_batch_size': 4,
    'per_device_eval_batch_size': 4,
    'num_train_epochs': 2,
    'max_seq_length': 384,
    'max_steps': 100,
    'pad_to_max_length': True,
    'doc_stride': 128,
    'output_dir': '/opt/ml/model',
    'model_name_or_path': tokenizer_name,
}

est_local = sagemaker.estimator.Estimator(
    container_image_uri,
    role,
    train_instance_count=1,
    train_instance_type="local",
    base_job_name=job_name,
    hyperparameters=hyperparameters,
)
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %%
est_local.fit()

# %%
est_cloud = sagemaker.estimator.Estimator(
    container_image_uri,
    role,
    train_instance_count=1,
    train_instance_type="ml.p3.2xlarge",
    base_job_name=job_name,
    hyperparameters=hyperparameters,
)
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %%
est_cloud.fit()
# Out:
# 2022-06-15 06:21:25 Starting - Starting the training job...
# 2022-06-15 06:21:52 Starting - Preparing the instances for trainingProfilerReport-1655274085: InProgress
# .........
# 2022-06-15 06:23:25 Downloading - Downloading input data
# 2022-06-15 06:23:25 Training - Downloading the training image......................................bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2022-06-15 06:29:35,872 sagemaker-training-toolkit INFO     Imported framework sagemaker_pytorch_container.training
# 2022-06-15 06:29:35,884 sagemaker-training-toolkit INFO     Failed to parse hyperparameter dataset_name value squad to Json.
# Returning the value itself
# 2022-06-15 06:29:35,884 sagemaker-training-toolkit INFO     Failed to parse hyperparameter do_eval value True to Json.
# Returning the value itself
# 2022-06-15 06:29:35,884 sagemaker-training-toolkit INFO     Failed to parse hyperparameter do_train value True to Json.
# Returning the value itself
# 2022-06-15 06:29:35,884 sagemaker-training-toolkit INFO     Failed to parse hyperparameter fp16 value True to Json.
# Returning the value itself
# 2022-06-15 06:29:35,885 sagemaker-training-toolkit INFO     Failed to parse hyperparameter model_name_or_path value bert-large-uncased-whole-word-masking to Json.
# Returning the value itself
# 2022-06-15 06:29:35,885 sagemaker-training-toolkit INFO     Failed to parse hyperparameter output_dir value /opt/ml/model to Json.
# Returning the value itself
# 2022-06-15 06:29:35,885 sagemaker-training-toolkit INFO     Failed to parse hyperparameter pad_to_max_length value True to Json.
# Returning the value itself
# 2022-06-15 06:29:35,894 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2022-06-15 06:29:35,901 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2022-06-15 06:29:35,913 sagemaker-training-toolkit INFO     Failed to parse hyperparameter dataset_name value squad to Json.
# Returning the value itself
# 2022-06-15 06:29:35,913 sagemaker-training-toolkit INFO     Failed to parse hyperparameter do_eval value True to Json.
# Returning the value itself
# 2022-06-15 06:29:35,913 sagemaker-training-toolkit INFO     Failed to parse hyperparameter do_train value True to Json.
# Returning the value itself
# 2022-06-15 06:29:35,913 sagemaker-training-toolkit INFO     Failed to parse hyperparameter fp16 value True to Json.
# Returning the value itself
# 2022-06-15 06:29:35,913 sagemaker-training-toolkit INFO     Failed to parse hyperparameter model_name_or_path value bert-large-uncased-whole-word-masking to Json.
# Returning the value itself
# 2022-06-15 06:29:35,914 sagemaker-training-toolkit INFO     Failed to parse hyperparameter output_dir value /opt/ml/model to Json.
# Returning the value itself
# 2022-06-15 06:29:35,914 sagemaker-training-toolkit INFO     Failed to parse hyperparameter pad_to_max_length value True to Json.
# Returning the value itself
# 2022-06-15 06:29:35,933 sagemaker-training-toolkit INFO     Failed to parse hyperparameter dataset_name value squad to Json.
# Returning the value itself
# 2022-06-15 06:29:35,934 sagemaker-training-toolkit INFO     Failed to parse hyperparameter do_eval value True to Json.
# Returning the value itself
# 2022-06-15 06:29:35,934 sagemaker-training-toolkit INFO     Failed to parse hyperparameter do_train value True to Json.
# Returning the value itself
# 2022-06-15 06:29:35,934 sagemaker-training-toolkit INFO     Failed to parse hyperparameter fp16 value True to Json.
# Returning the value itself
# 2022-06-15 06:29:35,934 sagemaker-training-toolkit INFO     Failed to parse hyperparameter model_name_or_path value bert-large-uncased-whole-word-masking to Json.
# Returning the value itself
# 2022-06-15 06:29:35,934 sagemaker-training-toolkit INFO     Failed to parse hyperparameter output_dir value /opt/ml/model to Json.
# Returning the value itself
# 2022-06-15 06:29:35,934 sagemaker-training-toolkit INFO     Failed to parse hyperparameter pad_to_max_length value True to Json.
# Returning the value itself
# 2022-06-15 06:29:35,953 sagemaker-training-toolkit INFO     Failed to parse hyperparameter dataset_name value squad to Json.
# Returning the value itself
# 2022-06-15 06:29:35,954 sagemaker-training-toolkit INFO     Failed to parse hyperparameter do_eval value True to Json.
# Returning the value itself
# 2022-06-15 06:29:35,954 sagemaker-training-toolkit INFO     Failed to parse hyperparameter do_train value True to Json.
# Returning the value itself
# 2022-06-15 06:29:35,954 sagemaker-training-toolkit INFO     Failed to parse hyperparameter fp16 value True to Json.
# Returning the value itself
# 2022-06-15 06:29:35,954 sagemaker-training-toolkit INFO     Failed to parse hyperparameter model_name_or_path value bert-large-uncased-whole-word-masking to Json.
# Returning the value itself
# 2022-06-15 06:29:35,954 sagemaker-training-toolkit INFO     Failed to parse hyperparameter output_dir value /opt/ml/model to Json.
# Returning the value itself
# 2022-06-15 06:29:35,954 sagemaker-training-toolkit INFO     Failed to parse hyperparameter pad_to_max_length value True to Json.
# Returning the value itself
# 2022-06-15 06:29:35,965 sagemaker-training-toolkit INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {},
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "dataset_name": "squad",
#         "do_eval": "True",
#         "do_train": "True",
#         "doc_stride": 128,
#         "fp16": "True",
#         "max_seq_length": 384,
#         "max_steps": 100,
#         "model_name_or_path": "bert-large-uncased-whole-word-masking",
#         "num_train_epochs": 2,
#         "output_dir": "/opt/ml/model",
#         "pad_to_max_length": "True",
#         "per_device_eval_batch_size": 4,
#         "per_device_train_batch_size": 4
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {},
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "torch-hf-gpu-2022-06-14-01-2022-06-15-06-21-24-832",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "/opt/ml/code",
#     "module_name": "/opt/ml/code/train",
#     "network_interface_name": "eth0",
#     "num_cpus": 8,
#     "num_gpus": 1,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "current_instance_type": "ml.p3.2xlarge",
#         "current_group_name": "homogeneousCluster",
#         "hosts": [
#             "algo-1"
#         ],
#         "instance_groups": [
#             {
#                 "instance_group_name": "homogeneousCluster",
#                 "instance_type": "ml.p3.2xlarge",
#                 "hosts": [
#                     "algo-1"
#                 ]
#             }
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "/opt/ml/code/train.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"dataset_name":"squad","do_eval":"True","do_train":"True","doc_stride":128,"fp16":"True","max_seq_length":384,"max_steps":100,"model_name_or_path":"bert-large-uncased-whole-word-masking","num_train_epochs":2,"output_dir":"/opt/ml/model","pad_to_max_length":"True","per_device_eval_batch_size":4,"per_device_train_batch_size":4}
# SM_USER_ENTRY_POINT=/opt/ml/code/train.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.p3.2xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.p3.2xlarge"}],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=[]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=/opt/ml/code/train
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=8
# SM_NUM_GPUS=1
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=/opt/ml/code
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{},"current_host":"algo-1","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1"],"hyperparameters":{"dataset_name":"squad","do_eval":"True","do_train":"True","doc_stride":128,"fp16":"True","max_seq_length":384,"max_steps":100,"model_name_or_path":"bert-large-uncased-whole-word-masking","num_train_epochs":2,"output_dir":"/opt/ml/model","pad_to_max_length":"True","per_device_eval_batch_size":4,"per_device_train_batch_size":4},"input_config_dir":"/opt/ml/input/config","input_data_config":{},"input_dir":"/opt/ml/input","is_master":true,"job_name":"torch-hf-gpu-2022-06-14-01-2022-06-15-06-21-24-832","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"/opt/ml/code","module_name":"/opt/ml/code/train","network_interface_name":"eth0","num_cpus":8,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.p3.2xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.p3.2xlarge"}],"network_interface_name":"eth0"},"user_entry_point":"/opt/ml/code/train.py"}
# SM_USER_ARGS=["--dataset_name","squad","--do_eval","True","--do_train","True","--doc_stride","128","--fp16","True","--max_seq_length","384","--max_steps","100","--model_name_or_path","bert-large-uncased-whole-word-masking","--num_train_epochs","2","--output_dir","/opt/ml/model","--pad_to_max_length","True","--per_device_eval_batch_size","4","--per_device_train_batch_size","4"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_HP_DATASET_NAME=squad
# SM_HP_DO_EVAL=True
# SM_HP_DO_TRAIN=True
# SM_HP_DOC_STRIDE=128
# SM_HP_FP16=True
# SM_HP_MAX_SEQ_LENGTH=384
# SM_HP_MAX_STEPS=100
# SM_HP_MODEL_NAME_OR_PATH=bert-large-uncased-whole-word-masking
# SM_HP_NUM_TRAIN_EPOCHS=2
# SM_HP_OUTPUT_DIR=/opt/ml/model
# SM_HP_PAD_TO_MAX_LENGTH=True
# SM_HP_PER_DEVICE_EVAL_BATCH_SIZE=4
# SM_HP_PER_DEVICE_TRAIN_BATCH_SIZE=4
# PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python38.zip:/opt/conda/lib/python3.8:/opt/conda/lib/python3.8/lib-dynload:/opt/conda/lib/python3.8/site-packages
# Invoking script with the following command:
# /opt/conda/bin/python3.8 /opt/ml/code/train.py --dataset_name squad --do_eval True --do_train True --doc_stride 128 --fp16 True --max_seq_length 384 --max_steps 100 --model_name_or_path bert-large-uncased-whole-word-masking --num_train_epochs 2 --output_dir /opt/ml/model --pad_to_max_length True --per_device_eval_batch_size 4 --per_device_train_batch_size 4
# 06/15/2022 06:29:41 - WARNING - __main__ - Process rank: -1, device: cuda:0, n_gpu: 1distributed training: False, 16-bits training: True
# 06/15/2022 06:29:41 - INFO - __main__ - Training/evaluation parameters TrainingArguments(
# _n_gpu=1,
# adafactor=False,
# adam_beta1=0.9,
# adam_beta2=0.999,
# adam_epsilon=1e-08,
# auto_find_batch_size=False,
# bf16=False,
# bf16_full_eval=False,
# data_seed=None,
# dataloader_drop_last=False,
# dataloader_num_workers=0,
# dataloader_pin_memory=True,
# ddp_bucket_cap_mb=None,
# ddp_find_unused_parameters=None,
# debug=[],
# deepspeed=None,
# disable_tqdm=False,
# do_eval=True,
# do_predict=False,
# do_train=True,
# eval_accumulation_steps=None,
# eval_delay=0,
# eval_steps=None,
# evaluation_strategy=IntervalStrategy.NO,
# fp16=True,
# fp16_backend=auto,
# fp16_full_eval=False,
# fp16_opt_level=O1,
# fsdp=[],
# fsdp_min_num_params=0,
# full_determinism=False,
# gradient_accumulation_steps=1,
# gradient_checkpointing=False,
# greater_is_better=None,
# group_by_length=False,
# half_precision_backend=auto,
# hub_model_id=None,
# hub_private_repo=False,
# hub_strategy=HubStrategy.EVERY_SAVE,
# hub_token=<HUB_TOKEN>,
# ignore_data_skip=False,
# include_inputs_for_metrics=False,
# label_names=None,
# label_smoothing_factor=0.0,
# learning_rate=5e-05,
# length_column_name=length,
# load_best_model_at_end=False,
# local_rank=-1,
# log_level=-1,
# log_level_replica=-1,
# log_on_each_node=True,
# logging_dir=/opt/ml/model/runs/Jun15_06-29-41_algo-1,
# logging_first_step=False,
# logging_nan_inf_filter=True,
# logging_steps=500,
# logging_strategy=IntervalStrategy.STEPS,
# lr_scheduler_type=SchedulerType.LINEAR,
# max_grad_norm=1.0,
# max_steps=100,
# metric_for_best_model=None,
# mp_parameters=,
# no_cuda=False,
# num_train_epochs=2.0,
# optim=OptimizerNames.ADAMW_HF,
# output_dir=/opt/ml/model,
# overwrite_output_dir=False,
# past_index=-1,
# per_device_eval_batch_size=4,
# per_device_train_batch_size=4,
# prediction_loss_only=False,
# push_to_hub=False,
# push_to_hub_model_id=None,
# push_to_hub_organization=None,
# push_to_hub_token=<PUSH_TO_HUB_TOKEN>,
# remove_unused_columns=True,
# report_to=[],
# resume_from_checkpoint=None,
# run_name=/opt/ml/model,
# save_on_each_node=False,
# save_steps=500,
# save_strategy=IntervalStrategy.STEPS,
# save_total_limit=None,
# seed=42,
# sharded_ddp=[],
# skip_memory_metrics=True,
# tf32=None,
# tpu_metrics_debug=False,
# tpu_num_cores=None,
# use_legacy_prediction_loop=False,
# warmup_ratio=0.0,
# warmup_steps=0,
# weight_decay=0.0,
# xpu_backend=None,
# )
# 06/15/2022 06:29:42 - INFO - datasets.utils.file_utils - https://raw.githubusercontent.com/huggingface/datasets/2.2.0/datasets/squad/squad.py not found in cache or force_download set to True, downloading to /root/.cache/huggingface/datasets/downloads/tmpoqzja9b6
# 06/15/2022 06:29:42 - INFO - datasets.utils.file_utils - storing https://raw.githubusercontent.com/huggingface/datasets/2.2.0/datasets/squad/squad.py in cache at /root/.cache/huggingface/datasets/downloads/e15e9c1bfb0ed35b5b3246f59d186eaf1f14c805071f0621390ea512017ba5fb.88910a81ad509b864eb2728ed18e25076f86eaa3cd11c5587ab5ceea8903a4bc.py
# 06/15/2022 06:29:42 - INFO - datasets.utils.file_utils - creating metadata file for /root/.cache/huggingface/datasets/downloads/e15e9c1bfb0ed35b5b3246f59d186eaf1f14c805071f0621390ea512017ba5fb.88910a81ad509b864eb2728ed18e25076f86eaa3cd11c5587ab5ceea8903a4bc.py
# 06/15/2022 06:29:42 - INFO - datasets.utils.file_utils - https://raw.githubusercontent.com/huggingface/datasets/2.2.0/datasets/squad/dataset_infos.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/datasets/downloads/tmpwsd4y3dg
# 06/15/2022 06:29:42 - INFO - datasets.utils.file_utils - storing https://raw.githubusercontent.com/huggingface/datasets/2.2.0/datasets/squad/dataset_infos.json in cache at /root/.cache/huggingface/datasets/downloads/0da665d7074d4a9486d6f562de7b42cf00044998da41f25685e6b2de047fa5fa.36bd0df82ceb24eeafc05394b25c534952fd7b2eaacf2b1f49933a8330f5800b
# 06/15/2022 06:29:42 - INFO - datasets.utils.file_utils - creating metadata file for /root/.cache/huggingface/datasets/downloads/0da665d7074d4a9486d6f562de7b42cf00044998da41f25685e6b2de047fa5fa.36bd0df82ceb24eeafc05394b25c534952fd7b2eaacf2b1f49933a8330f5800b
# 06/15/2022 06:29:42 - INFO - datasets.builder - No config specified, defaulting to the single config: squad/plain_text
# 06/15/2022 06:29:42 - INFO - datasets.info - Loading Dataset Infos from /root/.cache/huggingface/modules/datasets_modules/datasets/squad/d6ec3ceb99ca480ce37cdd35555d6cb2511d223b9150cce08a837ef62ffea453
# 06/15/2022 06:29:42 - INFO - datasets.builder - Generating dataset squad (/root/.cache/huggingface/datasets/squad/plain_text/1.0.0/d6ec3ceb99ca480ce37cdd35555d6cb2511d223b9150cce08a837ef62ffea453)
# Downloading and preparing dataset squad/plain_text (download: 33.51 MiB, generated: 85.63 MiB, post-processed: Unknown size, total: 119.14 MiB) to /root/.cache/huggingface/datasets/squad/plain_text/1.0.0/d6ec3ceb99ca480ce37cdd35555d6cb2511d223b9150cce08a837ef62ffea453...
# 06/15/2022 06:29:42 - INFO - datasets.builder - Dataset not on Hf google storage. Downloading and preparing it from source
# 06/15/2022 06:29:42 - INFO - datasets.utils.file_utils - https://rajpurkar.github.io/SQuAD-explorer/dataset/train-v1.1.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/datasets/downloads/tmp8xx5i8kk
# 06/15/2022 06:29:42 - INFO - datasets.utils.file_utils - storing https://rajpurkar.github.io/SQuAD-explorer/dataset/train-v1.1.json in cache at /root/.cache/huggingface/datasets/downloads/b8bb19735e1bb591510a01cc032f4c9f969bc0eeb081ae1b328cd306f3b24008
# 06/15/2022 06:29:42 - INFO - datasets.utils.file_utils - creating metadata file for /root/.cache/huggingface/datasets/downloads/b8bb19735e1bb591510a01cc032f4c9f969bc0eeb081ae1b328cd306f3b24008
# 06/15/2022 06:29:42 - INFO - datasets.utils.file_utils - https://rajpurkar.github.io/SQuAD-explorer/dataset/dev-v1.1.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/datasets/downloads/tmpl0nb5knm
# 06/15/2022 06:29:43 - INFO - datasets.utils.file_utils - storing https://rajpurkar.github.io/SQuAD-explorer/dataset/dev-v1.1.json in cache at /root/.cache/huggingface/datasets/downloads/9d5462987ef5f814fe15a369c1724f6ec39a2018b3b6271a9d7d2598686ca2ff
# 06/15/2022 06:29:43 - INFO - datasets.utils.file_utils - creating metadata file for /root/.cache/huggingface/datasets/downloads/9d5462987ef5f814fe15a369c1724f6ec39a2018b3b6271a9d7d2598686ca2ff
# 06/15/2022 06:29:43 - INFO - datasets.utils.download_manager - Downloading took 0.0 min
# 06/15/2022 06:29:43 - INFO - datasets.utils.download_manager - Checksum Computation took 0.0 min
# 06/15/2022 06:29:43 - INFO - datasets.utils.info_utils - All the checksums matched successfully for dataset source files
# 06/15/2022 06:29:43 - INFO - datasets.builder - Generating train split
#
# 2022-06-15 06:29:52 Training - Training image download completed. Training in progress.06/15/2022 06:29:50 - INFO - datasets.builder - Generating validation split
# 06/15/2022 06:29:51 - INFO - datasets.utils.info_utils - All the splits matched successfully.
# Dataset squad downloaded and prepared to /root/.cache/huggingface/datasets/squad/plain_text/1.0.0/d6ec3ceb99ca480ce37cdd35555d6cb2511d223b9150cce08a837ef62ffea453. Subsequent calls will reuse this data.
# [INFO|hub.py:583] 2022-06-15 06:29:51,574 >> https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/config.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpi528gcds
# [INFO|hub.py:587] 2022-06-15 06:29:51,858 >> storing https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/config.json in cache at /root/.cache/huggingface/transformers/86b0883704d931817042e5c354032897e1dd6ccd5c2260bf0f6d4a15a6e5a232.d4d29047141693194a1c377423a9a58b3ffdd39ed177b3a9b2ac9bce9e6638d9
# [INFO|hub.py:595] 2022-06-15 06:29:51,858 >> creating metadata file for /root/.cache/huggingface/transformers/86b0883704d931817042e5c354032897e1dd6ccd5c2260bf0f6d4a15a6e5a232.d4d29047141693194a1c377423a9a58b3ffdd39ed177b3a9b2ac9bce9e6638d9
# [INFO|configuration_utils.py:659] 2022-06-15 06:29:51,859 >> loading configuration file https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/86b0883704d931817042e5c354032897e1dd6ccd5c2260bf0f6d4a15a6e5a232.d4d29047141693194a1c377423a9a58b3ffdd39ed177b3a9b2ac9bce9e6638d9
# [INFO|configuration_utils.py:708] 2022-06-15 06:29:51,859 >> Model config BertConfig {
#   "_name_or_path": "bert-large-uncased-whole-word-masking",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.19.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
# [INFO|hub.py:583] 2022-06-15 06:29:52,137 >> https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/tokenizer_config.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmp2rj_1auf
# [INFO|hub.py:587] 2022-06-15 06:29:52,422 >> storing https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/tokenizer_config.json in cache at /root/.cache/huggingface/transformers/2a60ba33fe418e6652d2e5a6a40b189b0d6ca8a6a89e32a22bb5caf8d95982fe.20430bd8e10ef77a7d2977accefe796051e01bc2fc4aa146bc862997a1a15e79
# [INFO|hub.py:595] 2022-06-15 06:29:52,422 >> creating metadata file for /root/.cache/huggingface/transformers/2a60ba33fe418e6652d2e5a6a40b189b0d6ca8a6a89e32a22bb5caf8d95982fe.20430bd8e10ef77a7d2977accefe796051e01bc2fc4aa146bc862997a1a15e79
# [INFO|configuration_utils.py:659] 2022-06-15 06:29:52,704 >> loading configuration file https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/86b0883704d931817042e5c354032897e1dd6ccd5c2260bf0f6d4a15a6e5a232.d4d29047141693194a1c377423a9a58b3ffdd39ed177b3a9b2ac9bce9e6638d9
# [INFO|configuration_utils.py:708] 2022-06-15 06:29:52,704 >> Model config BertConfig {
#   "_name_or_path": "bert-large-uncased-whole-word-masking",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.19.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
# [INFO|hub.py:583] 2022-06-15 06:29:53,294 >> https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/vocab.txt not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpi70kr3wr
# [INFO|hub.py:587] 2022-06-15 06:29:53,832 >> storing https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/vocab.txt in cache at /root/.cache/huggingface/transformers/b6fcd4f8304ce7ce4a5462db5a53616f8464a083bbe20508ea92d5e07229086f.d789d64ebfe299b0e416afc4a169632f903f693095b4629a7ea271d5a0cf2c99
# [INFO|hub.py:595] 2022-06-15 06:29:53,832 >> creating metadata file for /root/.cache/huggingface/transformers/b6fcd4f8304ce7ce4a5462db5a53616f8464a083bbe20508ea92d5e07229086f.d789d64ebfe299b0e416afc4a169632f903f693095b4629a7ea271d5a0cf2c99
# [INFO|hub.py:583] 2022-06-15 06:29:54,143 >> https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/tokenizer.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpwn8q3yae
# [INFO|hub.py:587] 2022-06-15 06:29:54,775 >> storing https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/tokenizer.json in cache at /root/.cache/huggingface/transformers/33ee0bae279476c742373ecfd5a127d27372fbb9e2f5a84ccb38bbd72775f296.7f2721073f19841be16f41b0a70b600ca6b880c8f3df6f3535cbc704371bdfa4
# [INFO|hub.py:595] 2022-06-15 06:29:54,775 >> creating metadata file for /root/.cache/huggingface/transformers/33ee0bae279476c742373ecfd5a127d27372fbb9e2f5a84ccb38bbd72775f296.7f2721073f19841be16f41b0a70b600ca6b880c8f3df6f3535cbc704371bdfa4
# [INFO|tokenization_utils_base.py:1782] 2022-06-15 06:29:55,687 >> loading file https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/vocab.txt from cache at /root/.cache/huggingface/transformers/b6fcd4f8304ce7ce4a5462db5a53616f8464a083bbe20508ea92d5e07229086f.d789d64ebfe299b0e416afc4a169632f903f693095b4629a7ea271d5a0cf2c99
# [INFO|tokenization_utils_base.py:1782] 2022-06-15 06:29:55,688 >> loading file https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/tokenizer.json from cache at /root/.cache/huggingface/transformers/33ee0bae279476c742373ecfd5a127d27372fbb9e2f5a84ccb38bbd72775f296.7f2721073f19841be16f41b0a70b600ca6b880c8f3df6f3535cbc704371bdfa4
# [INFO|tokenization_utils_base.py:1782] 2022-06-15 06:29:55,688 >> loading file https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/added_tokens.json from cache at None
# [INFO|tokenization_utils_base.py:1782] 2022-06-15 06:29:55,688 >> loading file https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/special_tokens_map.json from cache at None
# [INFO|tokenization_utils_base.py:1782] 2022-06-15 06:29:55,688 >> loading file https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/tokenizer_config.json from cache at /root/.cache/huggingface/transformers/2a60ba33fe418e6652d2e5a6a40b189b0d6ca8a6a89e32a22bb5caf8d95982fe.20430bd8e10ef77a7d2977accefe796051e01bc2fc4aa146bc862997a1a15e79
# [INFO|configuration_utils.py:659] 2022-06-15 06:29:55,965 >> loading configuration file https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/86b0883704d931817042e5c354032897e1dd6ccd5c2260bf0f6d4a15a6e5a232.d4d29047141693194a1c377423a9a58b3ffdd39ed177b3a9b2ac9bce9e6638d9
# [INFO|configuration_utils.py:708] 2022-06-15 06:29:55,966 >> Model config BertConfig {
#   "_name_or_path": "bert-large-uncased-whole-word-masking",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.19.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
# [INFO|hub.py:583] 2022-06-15 06:29:56,361 >> https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/pytorch_model.bin not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpbx8briec
# [INFO|hub.py:587] 2022-06-15 06:30:15,768 >> storing https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/pytorch_model.bin in cache at /root/.cache/huggingface/transformers/fd59edc8ee9750d18ad7f5c4d97b4040bddfb6ccd64c37c421ffae14656dc51c.0bf22e1ed76b044bda5c02e02fdfc0bdf5a6e1827e76950cc9f43e1919ad896f
# [INFO|hub.py:595] 2022-06-15 06:30:15,768 >> creating metadata file for /root/.cache/huggingface/transformers/fd59edc8ee9750d18ad7f5c4d97b4040bddfb6ccd64c37c421ffae14656dc51c.0bf22e1ed76b044bda5c02e02fdfc0bdf5a6e1827e76950cc9f43e1919ad896f
# [INFO|modeling_utils.py:1953] 2022-06-15 06:30:15,769 >> loading weights file https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/pytorch_model.bin from cache at /root/.cache/huggingface/transformers/fd59edc8ee9750d18ad7f5c4d97b4040bddfb6ccd64c37c421ffae14656dc51c.0bf22e1ed76b044bda5c02e02fdfc0bdf5a6e1827e76950cc9f43e1919ad896f
# [WARNING|modeling_utils.py:2254] 2022-06-15 06:30:20,958 >> Some weights of the model checkpoint at bert-large-uncased-whole-word-masking were not used when initializing BertForQuestionAnswering: ['cls.predictions.decoder.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# [WARNING|modeling_utils.py:2265] 2022-06-15 06:30:20,959 >> Some weights of BertForQuestionAnswering were not initialized from the model checkpoint at bert-large-uncased-whole-word-masking and are newly initialized: ['qa_outputs.weight', 'qa_outputs.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 06/15/2022 06:30:21 - INFO - datasets.arrow_dataset - Caching processed dataset at /root/.cache/huggingface/datasets/squad/plain_text/1.0.0/d6ec3ceb99ca480ce37cdd35555d6cb2511d223b9150cce08a837ef62ffea453/cache-45ae4b53322548b6.arrow
# 06/15/2022 06:30:59 - INFO - datasets.arrow_dataset - Caching processed dataset at /root/.cache/huggingface/datasets/squad/plain_text/1.0.0/d6ec3ceb99ca480ce37cdd35555d6cb2511d223b9150cce08a837ef62ffea453/cache-f83a537363945e1b.arrow
# 06/15/2022 06:31:40 - INFO - datasets.utils.file_utils - https://raw.githubusercontent.com/huggingface/datasets/2.2.0/metrics/squad/squad.py not found in cache or force_download set to True, downloading to /root/.cache/huggingface/datasets/downloads/tmp13gdhxjd
# 06/15/2022 06:31:40 - INFO - datasets.utils.file_utils - storing https://raw.githubusercontent.com/huggingface/datasets/2.2.0/metrics/squad/squad.py in cache at /root/.cache/huggingface/datasets/downloads/7da45d040792aa6c53639df61ff2715803910e12024ec39f2a0124fef2a08d32.391a9da0201eab4bd2cc35b16f80e4bc05c0ef76af7d1006e3afe33a3188d76f.py
# 06/15/2022 06:31:40 - INFO - datasets.utils.file_utils - creating metadata file for /root/.cache/huggingface/datasets/downloads/7da45d040792aa6c53639df61ff2715803910e12024ec39f2a0124fef2a08d32.391a9da0201eab4bd2cc35b16f80e4bc05c0ef76af7d1006e3afe33a3188d76f.py
# 06/15/2022 06:31:40 - INFO - datasets.utils.file_utils - https://raw.githubusercontent.com/huggingface/datasets/2.2.0/metrics/squad/evaluate.py not found in cache or force_download set to True, downloading to /root/.cache/huggingface/datasets/downloads/tmpfqth_8yd
# 06/15/2022 06:31:40 - INFO - datasets.utils.file_utils - storing https://raw.githubusercontent.com/huggingface/datasets/2.2.0/metrics/squad/evaluate.py in cache at /root/.cache/huggingface/datasets/downloads/76b7eb42db25d25f5f7c6c385f2b3bf3dc421853b412424d5ec742880deaa799.6f69c3ff9e10aa1cbdc6e91d27e158ea86a785f54a36a9e964ef8b3b78cf3cd6.py
# 06/15/2022 06:31:40 - INFO - datasets.utils.file_utils - creating metadata file for /root/.cache/huggingface/datasets/downloads/76b7eb42db25d25f5f7c6c385f2b3bf3dc421853b412424d5ec742880deaa799.6f69c3ff9e10aa1cbdc6e91d27e158ea86a785f54a36a9e964ef8b3b78cf3cd6.py
# [INFO|trainer.py:470] 2022-06-15 06:31:43,987 >> max_steps is given, it will override any value given in num_train_epochs
# [INFO|trainer.py:502] 2022-06-15 06:31:43,987 >> Using amp half precision backend
# [INFO|trainer.py:1419] 2022-06-15 06:31:44,002 >> ***** Running training *****
# [INFO|trainer.py:1420] 2022-06-15 06:31:44,003 >>   Num examples = 88524
# [INFO|trainer.py:1421] 2022-06-15 06:31:44,003 >>   Num Epochs = 1
# [INFO|trainer.py:1422] 2022-06-15 06:31:44,003 >>   Instantaneous batch size per device = 4
# [INFO|trainer.py:1423] 2022-06-15 06:31:44,003 >>   Total train batch size (w. parallel, distributed & accumulation) = 4
# [INFO|trainer.py:1424] 2022-06-15 06:31:44,003 >>   Gradient Accumulation steps = 1
# [INFO|trainer.py:1425] 2022-06-15 06:31:44,003 >>   Total optimization steps = 100
# [2022-06-15 06:31:44.240 algo-1:22 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2022-06-15 06:31:44.357 algo-1:22 INFO profiler_config_parser.py:102] User has disabled profiler.
# 06/15/2022 06:34:49 - INFO - utils_qa - Post-processing 10570 example predictions split into 10784 features.
# 06/15/2022 06:35:21 - INFO - utils_qa - Saving predictions to /opt/ml/model/eval_predictions.json.
# 06/15/2022 06:35:21 - INFO - utils_qa - Saving nbest_preds to /opt/ml/model/eval_nbest_predictions.json.
#
# 2022-06-15 06:35:35 Uploading - Uploading generated training model06/15/2022 06:35:27 - INFO - datasets.metric - Removing /root/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# ***** eval metrics *****
#   epoch            =     0.0
#   eval_exact_match =  13.141
#   eval_f1          = 20.2572
#   eval_samples     =   10784
# [INFO|modelcard.py:460] 2022-06-15 06:35:27,334 >> Dropping the following result as it does not have all the necessary fields:
# {'task': {'name': 'Question Answering', 'type': 'question-answering'}, 'dataset': {'name': 'squad', 'type': 'squad', 'args': 'plain_text'}}
# #015Downloading builder script:   0%|          | 0.00/1.97k [00:00<?, ?B/s]#015Downloading builder script: 5.27kB [00:00, 4.51MB/s]
# #015Downloading metadata:   0%|          | 0.00/1.02k [00:00<?, ?B/s]#015Downloading metadata: 2.36kB [00:00, 2.79MB/s]
# #015Downloading data files:   0%|          | 0/2 [00:00<?, ?it/s]
# #015Downloading data:   0%|          | 0.00/8.12M [00:00<?, ?B/s]#033[A
# #015Downloading data:  67%|██████▋   | 5.46M/8.12M [00:00<00:00, 54.6MB/s]#033[A
# #015Downloading data: 13.2MB [00:00, 68.2MB/s]                            #033[A
# #015Downloading data: 20.9MB [00:00, 72.0MB/s]#033[A
# #015Downloading data: 28.6MB [00:00, 74.1MB/s]#033[A#015Downloading data: 30.3MB [00:00, 71.8MB/s]
# #015Downloading data files:  50%|█████     | 1/2 [00:00<00:00,  1.99it/s]
# #015Downloading data:   0%|          | 0.00/1.05M [00:00<?, ?B/s]#033[A#015Downloading data: 4.85MB [00:00, 63.3MB/s]
# #015Downloading data files: 100%|██████████| 2/2 [00:00<00:00,  3.34it/s]#015Downloading data files: 100%|██████████| 2/2 [00:00<00:00,  3.03it/s]
# #015Extracting data files:   0%|          | 0/2 [00:00<?, ?it/s]#015Extracting data files: 100%|██████████| 2/2 [00:00<00:00, 1707.78it/s]
# #015Generating train split:   0%|          | 0/87599 [00:00<?, ? examples/s]#015Generating train split:   0%|          | 1/87599 [00:00<13:28:23,  1.81 examples/s]#015Generating train split:   2%|▏         | 1527/87599 [00:00<00:27, 3130.88 examples/s]#015Generating train split:   4%|▎         | 3140/87599 [00:00<00:13, 6076.17 examples/s]#015Generating train split:   5%|▌         | 4741/87599 [00:00<00:09, 8505.13 examples/s]#015Generating train split:   7%|▋         | 6289/87599 [00:00<00:07, 10308.49 examples/s]#015Generating train split:   9%|▉         | 7825/87599 [00:01<00:06, 11671.79 examples/s]#015Generating train split:  11%|█         | 9295/87599 [00:01<00:06, 12095.13 examples/s]#015Generating train split:  12%|█▏        | 10712/87599 [00:01<00:07, 9940.80 examples/s]#015Generating train split:  14%|█▍        | 12343/87599 [00:01<00:06, 11451.22 examples/s]#015Generating train split:  16%|█▌        | 13962/87599 [00:01<00:05, 12647.63 examples/s]#015Generating train split:  18%|█▊        | 15381/87599 [00:01<00:07, 9787.70 examples/s] #015Generating train split:  19%|█▉        | 16994/87599 [00:01<00:06, 11191.79 examples/s]#015Generating train split:  21%|██        | 18593/87599 [00:01<00:05, 12343.80 examples/s]#015Generating train split:  23%|██▎       | 20000/87599 [00:02<00:05, 11740.65 examples/s]#015Generating train split:  25%|██▍       | 21647/87599 [00:02<00:05, 12926.35 examples/s]#015Generating train split:  27%|██▋       | 23286/87599 [00:02<00:04, 13838.54 examples/s]#015Generating train split:  28%|██▊       | 24925/87599 [00:02<00:04, 14536.92 examples/s]#015Generating train split:  30%|███       | 26561/87599 [00:02<00:04, 15049.25 examples/s]#015Generating train split:  32%|███▏      | 28120/87599 [00:02<00:03, 15201.94 examples/s]#015Generating train split:  34%|███▍      | 29677/87599 [00:02<00:03, 14509.34 examples/s]#015Generating train split:  36%|███▌      | 31159/87599 [00:02<00:04, 12150.30 examples/s]#015Generating train split:  37%|███▋      | 32483/87599 [00:03<00:04, 12422.25 examples/s]#015Generating train split:  39%|███▉      | 33961/87599 [00:03<00:04, 13043.42 examples/s]#015Generating train split:  41%|████      | 35588/87599 [00:03<00:03, 13925.74 examples/s]#015Generating train split:  42%|████▏     | 37026/87599 [00:03<00:04, 10486.00 examples/s]#015Generating train split:  44%|████▍     | 38668/87599 [00:03<00:04, 11852.93 examples/s]#015Generating train split:  46%|████▌     | 40002/87599 [00:03<00:04, 11251.58 examples/s]#015Generating train split:  48%|████▊     | 41655/87599 [00:03<00:03, 12548.03 examples/s]#015Generating train split:  49%|████▉     | 43279/87599 [00:03<00:03, 13507.06 examples/s]#015Generating train split:  51%|█████     | 44890/87599 [00:03<00:03, 14210.64 examples/s]#015Generating train split:  53%|█████▎    | 46492/87599 [00:04<00:02, 14714.68 examples/s]#015Generating train split:  55%|█████▍    | 48118/87599 [00:04<00:02, 15154.12 examples/s]#015Generating train split:  57%|█████▋    | 49754/87599 [00:04<00:02, 15500.40 examples/s]#015Generating train split:  59%|█████▊    | 51333/87599 [00:04<00:02, 13689.62 examples/s]#015Generating train split:  60%|██████    | 52982/87599 [00:04<00:02, 14439.47 examples/s]#015Generating train split:  62%|██████▏   | 54647/87599 [00:04<00:02, 15050.13 examples/s]#015Generating train split:  64%|██████▍   | 56300/87599 [00:04<00:02, 15465.44 examples/s]#015Generating train split:  66%|██████▌   | 57943/87599 [00:04<00:01, 15740.88 examples/s]#015Generating train split:  68%|██████▊   | 59577/87599 [00:04<00:01, 15912.99 examples/s]#015Generating train split:  70%|██████▉   | 61185/87599 [00:05<00:02, 10573.75 examples/s]#015Generating train split:  72%|███████▏  | 62804/87599 [00:05<00:02, 11795.89 examples/s]#015Generating train split:  74%|███████▎  | 64419/87599 [00:05<00:01, 12827.48 examples/s]#015Generating train split:  75%|███████▌  | 66034/87599 [00:05<00:01, 13667.78 examples/s]#015Generating train spli ...
# [INFO|hub.py:583] 2022-06-15 06:29:51,574 >> https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/config.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpi528gcds
# 2022-06-15 06:35:28,144 sagemaker-training-toolkit INFO     Reporting training SUCCESS
# #015Downloading:   0%|          | 0.00/434 [00:00<?, ?B/s]#015Downloading: 100%|██████████| 434/434 [00:00<00:00, 513kB/s]
# [INFO|hub.py:587] 2022-06-15 06:29:51,858 >> storing https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/config.json in cache at /root/.cache/huggingface/transformers/86b0883704d931817042e5c354032897e1dd6ccd5c2260bf0f6d4a15a6e5a232.d4d29047141693194a1c377423a9a58b3ffdd39ed177b3a9b2ac9bce9e6638d9
# [INFO|hub.py:595] 2022-06-15 06:29:51,858 >> creating metadata file for /root/.cache/huggingface/transformers/86b0883704d931817042e5c354032897e1dd6ccd5c2260bf0f6d4a15a6e5a232.d4d29047141693194a1c377423a9a58b3ffdd39ed177b3a9b2ac9bce9e6638d9
# [INFO|configuration_utils.py:659] 2022-06-15 06:29:51,859 >> loading configuration file https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/86b0883704d931817042e5c354032897e1dd6ccd5c2260bf0f6d4a15a6e5a232.d4d29047141693194a1c377423a9a58b3ffdd39ed177b3a9b2ac9bce9e6638d9
# [INFO|configuration_utils.py:708] 2022-06-15 06:29:51,859 >> Model config BertConfig {
#   "_name_or_path": "bert-large-uncased-whole-word-masking",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.19.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
# [INFO|hub.py:583] 2022-06-15 06:29:52,137 >> https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/tokenizer_config.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmp2rj_1auf
# #015Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]#015Downloading: 100%|██████████| 28.0/28.0 [00:00<00:00, 40.2kB/s]
# [INFO|hub.py:587] 2022-06-15 06:29:52,422 >> storing https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/tokenizer_config.json in cache at /root/.cache/huggingface/transformers/2a60ba33fe418e6652d2e5a6a40b189b0d6ca8a6a89e32a22bb5caf8d95982fe.20430bd8e10ef77a7d2977accefe796051e01bc2fc4aa146bc862997a1a15e79
# [INFO|hub.py:595] 2022-06-15 06:29:52,422 >> creating metadata file for /root/.cache/huggingface/transformers/2a60ba33fe418e6652d2e5a6a40b189b0d6ca8a6a89e32a22bb5caf8d95982fe.20430bd8e10ef77a7d2977accefe796051e01bc2fc4aa146bc862997a1a15e79
# [INFO|configuration_utils.py:659] 2022-06-15 06:29:52,704 >> loading configuration file https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/86b0883704d931817042e5c354032897e1dd6ccd5c2260bf0f6d4a15a6e5a232.d4d29047141693194a1c377423a9a58b3ffdd39ed177b3a9b2ac9bce9e6638d9
# [INFO|configuration_utils.py:708] 2022-06-15 06:29:52,704 >> Model config BertConfig {
#   "_name_or_path": "bert-large-uncased-whole-word-masking",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.19.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
# [INFO|hub.py:583] 2022-06-15 06:29:53,294 >> https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/vocab.txt not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpi70kr3wr
# #015Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]#015Downloading:  37%|███▋      | 84.0k/226k [00:00<00:00, 678kB/s]#015Downloading: 100%|██████████| 226k/226k [00:00<00:00, 1.20MB/s]
# [INFO|hub.py:587] 2022-06-15 06:29:53,832 >> storing https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/vocab.txt in cache at /root/.cache/huggingface/transformers/b6fcd4f8304ce7ce4a5462db5a53616f8464a083bbe20508ea92d5e07229086f.d789d64ebfe299b0e416afc4a169632f903f693095b4629a7ea271d5a0cf2c99
# [INFO|hub.py:595] 2022-06-15 06:29:53,832 >> creating metadata file for /root/.cache/huggingface/transformers/b6fcd4f8304ce7ce4a5462db5a53616f8464a083bbe20508ea92d5e07229086f.d789d64ebfe299b0e416afc4a169632f903f693095b4629a7ea271d5a0cf2c99
# [INFO|hub.py:583] 2022-06-15 06:29:54,143 >> https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/tokenizer.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpwn8q3yae
# #015Downloading:   0%|          | 0.00/455k [00:00<?, ?B/s]#015Downloading:   8%|▊         | 36.0k/455k [00:00<00:01, 280kB/s]#015Downloading:  41%|████▏     | 188k/455k [00:00<00:00, 899kB/s] #015Downloading: 100%|██████████| 455k/455k [00:00<00:00, 1.40MB/s]
# [INFO|hub.py:587] 2022-06-15 06:29:54,775 >> storing https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/tokenizer.json in cache at /root/.cache/huggingface/transformers/33ee0bae279476c742373ecfd5a127d27372fbb9e2f5a84ccb38bbd72775f296.7f2721073f19841be16f41b0a70b600ca6b880c8f3df6f3535cbc704371bdfa4
# [INFO|hub.py:595] 2022-06-15 06:29:54,775 >> creating metadata file for /root/.cache/huggingface/transformers/33ee0bae279476c742373ecfd5a127d27372fbb9e2f5a84ccb38bbd72775f296.7f2721073f19841be16f41b0a70b600ca6b880c8f3df6f3535cbc704371bdfa4
# [INFO|tokenization_utils_base.py:1782] 2022-06-15 06:29:55,687 >> loading file https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/vocab.txt from cache at /root/.cache/huggingface/transformers/b6fcd4f8304ce7ce4a5462db5a53616f8464a083bbe20508ea92d5e07229086f.d789d64ebfe299b0e416afc4a169632f903f693095b4629a7ea271d5a0cf2c99
# [INFO|tokenization_utils_base.py:1782] 2022-06-15 06:29:55,688 >> loading file https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/tokenizer.json from cache at /root/.cache/huggingface/transformers/33ee0bae279476c742373ecfd5a127d27372fbb9e2f5a84ccb38bbd72775f296.7f2721073f19841be16f41b0a70b600ca6b880c8f3df6f3535cbc704371bdfa4
# [INFO|tokenization_utils_base.py:1782] 2022-06-15 06:29:55,688 >> loading file https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/added_tokens.json from cache at None
# [INFO|tokenization_utils_base.py:1782] 2022-06-15 06:29:55,688 >> loading file https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/special_tokens_map.json from cache at None
# [INFO|tokenization_utils_base.py:1782] 2022-06-15 06:29:55,688 >> loading file https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/tokenizer_config.json from cache at /root/.cache/huggingface/transformers/2a60ba33fe418e6652d2e5a6a40b189b0d6ca8a6a89e32a22bb5caf8d95982fe.20430bd8e10ef77a7d2977accefe796051e01bc2fc4aa146bc862997a1a15e79
# [INFO|configuration_utils.py:659] 2022-06-15 06:29:55,965 >> loading configuration file https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/86b0883704d931817042e5c354032897e1dd6ccd5c2260bf0f6d4a15a6e5a232.d4d29047141693194a1c377423a9a58b3ffdd39ed177b3a9b2ac9bce9e6638d9
# [INFO|configuration_utils.py:708] 2022-06-15 06:29:55,966 >> Model config BertConfig {
#   "_name_or_path": "bert-large-uncased-whole-word-masking",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.19.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
# [INFO|hub.py:583] 2022-06-15 06:29:56,361 >> https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/pytorch_model.bin not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpbx8briec
# ...
# #015 20%|█▉        | 2063/10570 [00:05<00:26, 319.78it/s]#033[A
# #015 20%|█▉        | 2102/10570 [00:06<00:25, 338.00it/s]#033[A
# #015 20%|██        | 2136/10570 [00:06<00:26, 317.85it/s]#033[A
# #015 21%|██        | 2173/10570 [00:06<00:25, 329.66it/s]#033[A
# #015 21%|██        | 2211/10570 [00:06<00:24, 342.23it/s]#033[A
# #015 21%|██▏       | 2249/10570 [00:06<00:23, 350.90it/s]#033[A
# #015 22%|██▏       | 2286/10570 [00:06<00:23, 356.35it/s]#033[A
# #015 22%|██▏       | 2323/10570 [00:06<00:22, 359.89it/s]#033[A
# #015 22%|██▏       | 2361/10570 [00:06<00:22, 363.23it/s]#033[A
# #015 23%|██▎       | 2398/10570 [00:06<00:22, 359.80it/s]#033[A
# #015 23%|██▎       | 2435/10570 [00:06<00:22, 359.45it/s]#033[A
# #015 23%|██▎       | 2471/10570 [00:07<00:22, 356.62it/s]#033[A
# #015 24%|██▎       | 2507/10570 [00:07<00:23, 341.21it/s]#033[A
# #015 24%|██▍       | 2542/10570 [00:07<00:23, 342.47it/s]#033[A
# #015 24%|██▍       | 2577/10570 [00:07<00:23, 336.00it/s]#033[A
# #015 25%|██▍       | 2611/10570 [00:07<00:24, 324.17it/s]#033[A
# #015 25%|██▌       | 2644/10570 [00:07<00:24, 318.95it/s]#033[A
# #015 25%|██▌       | 2676/10570 [00:07<00:25, 314.00it/s]#033[A
# #015 26%|██▌       | 2708/10570 [00:07<00:25, 308.01it/s]#033[A
# #015 26%|██▌       | 2739/10570 [00:07<00:25, 307.89it/s]#033[A
# #015 26%|██▌       | 2772/10570 [00:08<00:25, 311.48it/s]#033[A
# #015 27%|██▋       | 2804/10570 [00:08<00:24, 312.71it/s]#033[A
# #015 27%|██▋       | 2836/10570 [00:08<00:25, 307.33it/s]#033[A
# #015 27%|██▋       | 2872/10570 [00:08<00:23, 321.55it/s]#033[A
# #015 28%|██▊       | 2908/10570 [00:08<00:23, 332.01it/s]#033[A
# #015 28%|██▊       | 2946/10570 [00:08<00:22, 343.80it/s]#033[A
# #015 28%|██▊       | 2983/10570 [00:08<00:21, 349.94it/s]#033[A
# #015 29%|██▊       | 3019/10570 [00:08<00:22, 342.94it/s]#033[A
# #015 29%|██▉       | 3054/10570 [00:08<00:22, 327.47it/s]#033[A
# #015 29%|██▉       | 3090/10570 [00:08<00:22, 336.06it/s]#033[A
# #015 30%|██▉       | 3127/10570 [00:09<00:21, 344.72it/s]#033[A
# #015 30%|██▉       | 3163/10570 [00:09<00:21, 346.93it/s]#033[A
# #015 30%|███       | 3199/10570 [00:09<00:21, 348.24it/s]#033[A
# #015 31%|███       | 3235/10570 [00:09<00:21, 348.84it/s]#033[A
# #015 31%|███       | 3271/10570 [00:09<00:20, 351.68it/s]#033[A
# #015 31%|███▏      | 3307/10570 [00:09<00:20, 352.40it/s]#033[A
# #015 32%|███▏      | 3345/10570 [00:09<00:20, 357.98it/s]#033[A
# #015 32%|███▏      | 3381/10570 [00:09<00:20, 354.81it/s]#033[A
# #015 32%|███▏      | 3417/10570 [00:09<00:20, 351.38it/s]#033[A
# #015 33%|███▎      | 3454/10570 [00:09<00:20, 355.02it/s]#033[A
# #015 33%|███▎      | 3490/10570 [00:10<00:20, 345.82it/s]#033[A
# #015 33%|███▎      | 3525/10570 [00:10<00:20, 341.63it/s]#033[A
# #015 34%|███▎      | 3561/10570 [00:10<00:20, 345.15it/s]#033[A
# #015 34%|███▍      | 3596/10570 [00:10<00:20, 346.44it/s]#033[A
# #015 34%|███▍      | 3633/10570 [00:10<00:19, 352.11it/s]#033[A
# #015 35%|███▍      | 3670/10570 [00:10<00:19, 354.55it/s]#033[A
# #015 35%|███▌      | 3707/10570 [00:10<00:19, 356.60it/s]#033[A
# #015 35%|███▌      | 3743/10570 [00:10<00:19, 356.37it/s]#033[A
# #015 36%|███▌      | 3782/10570 [00:10<00:18, 363.60it/s]#033[A
# #015 36%|███▌      | 3819/10570 [00:11<00:18, 356.72it/s]#033[A
# #015 36%|███▋      | 3856/10570 [00:11<00:18, 358.21it/s]#033[A
# #015 37%|███▋      | 3893/10570 [00:11<00:18, 359.42it/s]#033[A
# #015 37%|███▋      | 3930/10570 [00:11<00:18, 360.18it/s]#033[A
# #015 38%|███▊      | 3967/10570 [00:11<00:18, 358.85it/s]#033[A
# #015 38%|███▊      | 4003/10570 [00:11<00:18, 356.22it/s]#033[A
# #015 38%|███▊      | 4040/10570 [00:11<00:18, 357.85it/s]#033[A
# #015 39%|███▊      | 4078/10570 [00:11<00:17, 362.26it/s]#033[A
# #015 39%|███▉      | 4115/10570 [00:11<00:18, 347.25it/s]#033[A
# #015 39%|███▉      | 4150/10570 [00:12<00:23, 270.77it/s]#033[A
# #015 40%|███▉      | 4180/10570 [00:12<00:24, 257.29it/s]#033[A
# #015 40%|███▉      | 4208/10570 [00:12<00:28, 222.69it/s]#033[A
# #015 40%|████      | 4243/10570 [00:12<00:25, 250.48it/s]#033[A
# #015 40%|████      | 4271/10570 [00:12<00:28, 219.42it/s]#033[A
# #015 41%|████      | 4295/10570 [00:12<00:31, 202.22it/s]#033[A
# #015 41%|████      | 4317/10570 [00:12<00:31, 198.48it/s]#033[A
# #015 41%|████      | 4354/10570 [00:12<00:26, 238.62it/s]#033[A
# #015 42%|████▏     | 4390/10570 [00:13<00:22, 269.11it/s]#033[A
# #015 42%|████▏     | 4427/10570 [00:13<00:20, 294.15it/s]#033[A
# #015 42%|████▏     | 4465/10570 [00:13<00:19, 315.45it/s]#033[A
# #015 43%|████▎     | 4500/10570 [00:13<00:18, 323.77it/s]#033[A
# #015 43%|████▎     | 4534/10570 [00:13<00:18, 320.78it/s]#033[A
# #015 43%|████▎     | 4570/10570 [00:13<00:18, 330.15it/s]#033[A
# #015 44%|████▎     | 4604/10570 [00:13<00:18, 318.98it/s]#033[A
# #015 44%|████▍     | 4637/10570 [00:13<00:18, 318.42it/s]#033[A
# #015 44%|████▍     | 4670/10570 [00:13<00:19, 306.73it/s]#033[A
# #015 45%|████▍     | 4705/10570 [00:14<00:18, 317.71it/s]#033[A
# #015 45%|████▍     | 4738/10570 [00:14<00:18, 307.73it/s]#033[A
# #015 45%|████▌     | 4769/10570 [00:14<00:19, 299.18it/s]#033[A
# #015 45%|████▌     | 4800/10570 [00:14<00:19, 296.40it/s]#033[A
# #015 46%|████▌     | 4835/10570 [00:14<00:18, 308.74it/s]#033[A
# #015 46%|████▌     | 4867/10570 [00:14<00:20, 279.89it/s]#033[A
# #015 46%|████▋     | 4899/10570 [00:14<00:19, 289.69it/s]#033[A
# #015 47%|████▋     | 4929/10570 [00:14<00:19, 290.55it/s]#033[A
# #015 47%|████▋     | 4965/10570 [00:14<00:18, 308.60it/s]#033[A
# #015 47%|████▋     | 4999/10570 [00:15<00:17, 316.40it/s]#033[A
# #015 48%|████▊     | 5033/10570 [00:15<00:17, 322.78it/s]#033[A
# #015 48%|████▊     | 5068/10570 [00:15<00:16, 329.56it/s]#033[A
# #015 48%|████▊     | 5102/10570 [00:15<00:17, 306.88it/s]#033[A
# #015 49%|████▊     | 5135/10570 [00:15<00:17, 311.21it/s]#033[A
# #015 49%|████▉     | 5167/10570 [00:15<00:17, 308.96it/s]#033[A
# #015 49%|████▉     | 5199/10570 [00:15<00:17, 310.30it/s]#033[A
# #015 49%|████▉     | 5231/10570 [00:15<00:17, 302.61it/s]#033[A
# #015 50%|████▉     | 5262/10570 [00:15<00:18, 286.86it/s]#033[A
# #015 50%|█████     | 5292/10570 [00:16<00:18, 289.59it/s]#033[A
# #015 50%|█████     | 5324/10570 [00:16<00:17, 297.76it/s]#033[A
# #015 51%|█████     | 5358/10570 [00:16<00:16, 309.11it/s]#033[A
# #015 51%|█████     | 5394/10570 [00:16<00:15, 323.72it/s]#033[A
# #015 51%|█████▏    | 5430/10570 [00:16<00:15, 332.06it/s]#033[A
# #015 52%|█████▏    | 5464/10570 [00:16<00:16, 315.29it/s]#033[A
# #015 52%|█████▏    | 5496/10570 [00:16<00:16, 307.47it/s]#033[A
# #015 52%|█████▏    | 5530/10570 [00:16<00:16, 314.32it/s]#033[A
# #015 53%|█████▎    | 5562/10570 [00:16<00:15, 315.23it/s]#033[A
# #015 53%|█████▎    | 5598/10570 [00:16<00:15, 327.40it/s]#033[A
# #015 53%|█████▎    | 5632/10570 [00:17<00:15, 328.43it/s]#033[A
# #015 54%|█████▎    | 5665/10570 [00:17<00:15, 319.47it/s]#033[A
# #015 54%|█████▍    | 5702/10570 [00:17<00:14, 331.72it/s]#033[A
# #015 54%|█████▍    | 5738/10570 [00:17<00:14, 337.13it/s]#033[A
# #015 55%|█████▍    | 5773/10570 [00:17<00:14, 338.44it/s]#033[A
# #015 55%|█████▍    | 5808/10570 [00:17<00:14, 339.66it/s]#033[A
# #015 55%|█████▌    | 5844/10570 [00:17<00:13, 343.64it/s]#033[A
# #015 56%|█████▌    | 5880/10570 [00:17<00:13, 345.75it/s]#033[A
# #015 56%|█████▌    | 5915/10570 [00:17<00:13, 339.45it/s]#033[A
# #015 56%|█████▋    | 5950/10570 [00:17<00:13, 341.99it/s]#033[A
# #015 57%|█████▋    | 5986/10570 [00:18<00:13, 347.20it/s]#033[A
# #015 57%|█████▋    | 6021/10570 [00:18<00:13, 346.68it/s]#033[A
# #015 57%|█████▋    | 6056/10570 [00:18<00:13, 342.19it/s]#033[A
# #015 58%|█████▊    | 6091/10570 [00:18<00:13, 339.37it/s]#033[A
# #015 58%|█████▊    | 6126/10570 [00:18<00:12, 342.45it/s]#033[A
# #015 58%|█████▊    | 6163/10570 [00:18<00:12, 347.87it/s]#033[A
# #015 59%|█████▊    | 6199/10570 [00:18<00:12, 349.18it/s]#033[A
# #015 59%|█████▉    | 6234/10570 [00:18<00:13, 332.82it/s]#033[A
# #015 59%|█████▉    | 6269/10570 [00:18<00:12, 335.93it/s]#033[A
# #015 60%|█████▉    | 6306/10570 [00:19<00:12, 344.65it/s]#033[A
# #015 60%|██████    | 6342/10570 [00:19<00:12, 347.37it/s]#033[A
# #015 60%|██████    | 6377/10570 [00:19<00:12, 335.80it/s]#033[A
# #015 61%|██████    | 6413/10570 [00:19<00:12, 341.99it/s]#033[A
# #015 61%|██████    | 6450/10570 [00:19<00:11, 349.91it/s]#033[A
# #015 61%|██████▏   | 6487/10570 [00:19<00:11, 353.57it/s]#033[A
# #015 62%|██████▏   | 6523/10570 [00:19<00:11, 350.93it/s]#033[A
# #015 62%|██████▏   | 6559/10570 [00:19<00:11, 352.39it/s]#033[A
# #015 62%|██████▏   | 6595/10570 [00:19<00:11, 343.70it/s]#033[A
# #015 63%|██████▎   | 6632/10570 [00:19<00:11, 350.43it/s]#033[A
# #015 63%|██████▎   | 6668/10570 [00:20<00:11, 353.16it/s]#033[A
# #015 63%|██████▎   | 6704/10570 [00:20<00:11, 346.05it/s]#033[A
# #015 64%|██████▍   | 6739/10570 [00:20<00:11, 345.53it/s]#033[A
# #015 64%|██████▍   | 6776/10570 [00:20<00:10, 352.29it/s]#033[A
# #015 64%|██████▍   | 6812/10570 [00:20<00:10, 346.87it/s]#033[A
# #015 65%|██████▍   | 6847/10570 [00:20<00:10, 342.25it/s]#033[A
# #015 65%|██████▌   | 6882/10570 [00:20<00:10, 341.15it/s]#033[A
# #015 65%|██████▌   | 6917/10570 [00:20<00:10, 342.84it/s]#033[A
# #015 66%|██████▌   | 6954/10570 [00:20<00:10, 348.86it/s]#033[A
# #015 66%|██████▌   | 6991/10570 [00:20<00:10, 353.79it/s]#033[A
# #015 66%|██████▋   | 7028/10570 [00:21<00:09, 357.03it/s]#033[A
# #015 67%|██████▋   | 7064/10570 [00:21<00:09, 353.85it/s]#033[A
# #015 67%|██████▋   | 7101/10570 [00:21<00:09, 355.40it/s]#033[A
# #015 68%|██████▊   | 7137/10570 [00:21<00:09, 347.01it/s]#033[A
# #015 68%|██████▊   | 7172/10570 [00:21<00:10, 328.31it/s]#033[A
# #015 68%|██████▊   | 7206/10570 [00:21<00:10, 313.05it/s]#033[A
# #015 68%|██████▊   | 7238/10570 [00:21<00:11, 302.25it/s]#033[A
# #015 69%|██████▉   | 7269/10570 [00:21<00:11, 296.19it/s]#033[A
# #015 69%|██████▉   | 7299/10570 [00:21<00:11, 294.14it/s]#033[A
# #015 69%|██████▉   | 7332/10570 [00:22<00:10, 300.40it/s]#033[A
# #015 70%|██████▉   | 7363/10570 [00:22<00:11, 271.58it/s]#033[A
# #015 70%|██████▉   | 7391/10570 [00:22<00:11, 272.17it/s]#033[A
# #015 70%|███████   | 7428/10570 [00:22<00:10, 298.15it/s]#033[A
# #015 71%|███████   | 7463/10570 [00:22<00:09, 311.54it/s]#033[A
# #015 71%|███████   | 7500/10570 [00:22<00:09, 326.53it/s]#033[A
# #015 71%|███████▏  | 7537/10570 [00:22<00:08, 338.10it/s]#033[A
# #015 72%|███████▏  | 7574/10570 [00:22<00:08, 345.50it/s]#033[A
# #015 72%|███████▏  | 7609/10570 [00:22<00:08, 343.40it/s]#033[A
# #015 72%|███████▏  | 7644/10570 [00:23<00:08, 337.15it/s]#033[A
# #015 73%|███████▎  | 7678/10570 [00:23<00:08, 326.78it/s]#033[A
# #015 73%|███████▎  | 7714/10570 [00:23<00:08, 335.96it/s]#033[A
# #015 73%|███████▎  | 7748/10570 [00:23<00:08, 328.57it/s]#033[A
# #015 74%|███████▎  | 7782/10570 [00:23<00:08, 330.30it/s]#033[A
# #015 74%|███████▍  | 7817/10570 [00:23<00:08, 336.00it/s]#033[A
# #015 74%|███████▍  | 7853/10570 [00:23<00:07, 340.18it/s]#033[A
# #015 75%|███████▍  | 7888/10570 [00:23<00:07, 342.64it/s]#033[A
# #015 75%|███████▍  | 7924/10570 [00:23<00:07, 346.65it/s]#033[A
# #015 75%|███████▌  | 7960/10570 [00:23<00:07, 349.02it/s]#033[A
# #015 76%|███████▌  | 7995/10570 [00:24<00:07, 346.25it/s]#033[A
# #015 76%|███████▌  | 8030/10570 [00:24<00:07, 345.55it/s]#033[A
# #015 76%|███████▋  | 8065/10570 [00:24<00:07, 340.94it/s]#033[A
# #015 77%|███████▋  | 8101/10570 [00:24<00:07, 344.13it/s]#033[A
# #015 77%|███████▋  | 8137/10570 [00:24<00:07, 345.58it/s]#033[A
# #015 77%|███████▋  | 8172/10570 [00:24<00:07, 340.92it/s]#033[A
# #015 78%|███████▊  | 8207/10570 [00:24<00:06, 339.00it/s]#033[A
# #015 78%|███████▊  | 8241/10570 [00:24<00:07, 327.80it/s]#033[A
# #015 78%|███████▊  | 8274/10570 [00:24<00:07, 315.99it/s]#033[A
# #015 79%|███████▊  | 8306/10570 [00:25<00:07, 314.02it/s]#033[A
# #015 79%|███████▉  | 8341/10570 [00:25<00:06, 322.61it/s]#033[A
# #015 79%|███████▉  | 8377/10570 [00:25<00:06, 332.89it/s]#033[A
# #015 80%|███████▉  | 8414/10570 [00:25<00:06, 342.80it/s]#033[A
# #015 80%|███████▉  | 8451/10570 [00:25<00:06, 350.55it/s]#033[A
# #015 80%|████████  | 8488/10570 [00:25<00:05, 354.70it/s]#033[A
# #015 81%|████████  | 8524/10570 [00:25<00:05, 355.96it/s]#033[A
# #015 81%|████████  | 8561/10570 [00:25<00:05, 358.86it/s]#033[A
# #015 81%|████████▏ | 8597/10570 [00:25<00:05, 355.76it/s]#033[A
# #015 82%|████████▏ | 8633/10570 [00:25<00:05, 356.80it/s]#033[A
# #015 82%|████████▏ | 8669/10570 [00:26<00:05, 352.84it/s]#033[A
# #015 82%|████████▏ | 8706/10570 [00:26<00:05, 355.15it/s]#033[A
# #015 83%|████████▎ | 8742/10570 [00:26<00:05, 351.64it/s]#033[A
# #015 83%|████████▎ | 8778/10570 [00:26<00:05, 347.75it/s]#033[A
# #015 83%|████████▎ | 8813/10570 [00:26<00:05, 346.12it/s]#033[A
# #015 84%|████████▎ | 8849/10570 [00:26<00:04, 347.80it/s]#033[A
# #015 84%|████████▍ | 8886/10570 [00:26<00:04, 351.62it/s]#033[A
# #015 84%|████████▍ | 8922/10570 [00:26<00:04, 352.18it/s]#033[A
# #015 85%|████████▍ | 8958/10570 [00:26<00:04, 351.49it/s]#033[A
# #015 85%|████████▌ | 8994/10570 [00:26<00:04, 345.97it/s]#033[A
# #015 85%|████████▌ | 9030/10570 [00:27<00:04, 348.18it/s]#033[A
# #015 86%|████████▌ | 9065/10570 [00:27<00:04, 348.65it/s]#033[A
# #015 86%|████████▌ | 9100/10570 [00:27<00:04, 348.95it/s]#033[A
# #015 86%|████████▋ | 9136/10570 [00:27<00:04, 351.51it/s]#033[A
# #015 87%|████████▋ | 9172/10570 [00:27<00:03, 349.58it/s]#033[A
# #015 87%|████████▋ | 9208/10570 [00:27<00:03, 351.62it/s]#033[A
# #015 87%|████████▋ | 9245/10570 [00:27<00:03, 356.15it/s]#033[A
# #015 88%|████████▊ | 9282/10570 [00:27<00:03, 357.79it/s]#033[A
# #015 88%|████████▊ | 9318/10570 [00:27<00:03, 352.83it/s]#033[A
# #015 88%|████████▊ | 9354/10570 [00:27<00:03, 353.80it/s]#033[A
# #015 89%|████████▉ | 9390/10570 [00:28<00:03, 353.64it/s]#033[A
# #015 89%|████████▉ | 9426/10570 [00:28<00:03, 354.84it/s]#033[A
# #015 90%|████████▉ | 9463/10570 [00:28<00:03, 358.58it/s]#033[A
# #015 90%|████████▉ | 9499/10570 [00:28<00:02, 357.20it/s]#033[A
# #015 90%|█████████ | 9536/10570 [00:28<00:02, 357.32it/s]#033[A
# #015 91%|█████████ | 9572/10570 [00:28<00:02, 356.60it/s]#033[A
# #015 91%|█████████ | 9608/10570 [00:28<00:02, 357.21it/s]#033[A
# #015 91%|█████████ | 9645/10570 [00:28<00:02, 359.17it/s]#033[A
# #015 92%|█████████▏| 9682/10570 [00:28<00:02, 360.68it/s]#033[A
# #015 92%|█████████▏| 9720/10570 [00:29<00:02, 364.84it/s]#033[A
# #015 92%|█████████▏| 9757/10570 [00:29<00:02, 362.99it/s]#033[A
# #015 93%|█████████▎| 9794/10570 [00:29<00:02, 359.76it/s]#033[A
# #015 93%|█████████▎| 9830/10570 [00:29<00:02, 359.70it/s]#033[A
# #015 93%|█████████▎| 9866/10570 [00:29<00:01, 355.11it/s]#033[A
# #015 94%|█████████▎| 9902/10570 [00:29<00:01, 356.11it/s]#033[A
# #015 94%|█████████▍| 9939/10570 [00:29<00:01, 357.54it/s]#033[A
# #015 94%|█████████▍| 9975/10570 [00:29<00:01, 352.23it/s]#033[A
# #015 95%|█████████▍| 10011/10570 [00:29<00:01, 352.56it/s]#033[A
# #015 95%|█████████▌| 10048/10570 [00:29<00:01, 357.00it/s]#033[A
# #015 95%|█████████▌| 10084/10570 [00:30<00:01, 354.75it/s]#033[A
# #015 96%|█████████▌| 10121/10570 [00:30<00:01, 356.90it/s]#033[A
# #015 96%|█████████▌| 10158/10570 [00:30<00:01, 358.54it/s]#033[A
# #015 96%|█████████▋| 10194/10570 [00:30<00:01, 347.62it/s]#033[A
# #015 97%|█████████▋| 10231/10570 [00:30<00:00, 351.78it/s]#033[A
# #015 97%|█████████▋| 10267/10570 [00:30<00:00, 350.92it/s]#033[A
# #015 97%|█████████▋| 10304/10570 [00:30<00:00, 354.14it/s]#033[A
# #015 98%|█████████▊| 10340/10570 [00:30<00:00, 355.83it/s]#033[A
# #015 98%|█████████▊| 10376/10570 [00:30<00:00, 354.84it/s]#033[A
# #015 99%|█████████▊| 10412/10570 [00:30<00:00, 352.69it/s]#033[A
# #015 99%|█████████▉| 10448/10570 [00:31<00:00, 350.00it/s]#033[A
# #015 99%|█████████▉| 10484/10570 [00:31<00:00, 342.60it/s]#033[A
# #015100%|█████████▉| 10521/10570 [00:31<00:00, 348.99it/s]#033[A
# #015100%|█████████▉| 10558/10570 [00:31<00:00, 354.70it/s]#033[A#015100%|██████████| 10570/10570 [00:31<00:00, 336.47it/s]
# #015100%|██████████| 2696/2696 [03:18<00:00, 13.57it/s]
# [INFO|modelcard.py:460] 2022-06-15 06:35:27,334 >> Dropping the following result as it does not have all the necessary fields:
# {'task': {'name': 'Question Answering', 'type': 'question-answering'}, 'dataset': {'name': 'squad', 'type': 'squad', 'args': 'plain_text'}}
#
# 2022-06-15 06:38:40 Completed - Training job completed
# Training seconds: 930
# Billable seconds: 930

# %% [markdown]
# #### Display the last training job outputs

# %%
est_cloud.latest_job_profiler_artifacts_path()
# Out:
# 's3://sagemaker-us-west-2-976939723775/torch-hf-gpu-2022-06-14-01-2022-06-14-20-07-35-455/profiler-output'

# %%
# !aws s3 ls s3://sagemaker-us-west-2-976939723775/torch-hf-gpu-2022-06-14-01-2022-06-14-20-07-35-455/profiler-output/system/incremental/2022061420/
# Out:
# 2022-06-14 20:11:01     178208 1655237340.algo-1.json
# 2022-06-14 20:11:00     387964 1655237400.algo-1.json
# 2022-06-14 20:12:00     387850 1655237460.algo-1.json
# 2022-06-14 20:13:00     387536 1655237520.algo-1.json
# 2022-06-14 20:13:15      93641 1655237580.algo-1.json

# %% [markdown]
# ### Deploying the endpoint
# To deploy our endpoint, we call deploy() on our HuggingFace estimator object, passing in our desired number of instances and instance type.

# %%
predictor = est_cloud.deploy(1,"ml.m4.2xlarge")
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# <ipython-input-109-574c4c337c7b> in <module>
# ----> 1 predictor = est_cloud.deploy(1,"ml.m4.2xlarge")
#
# ~/anaconda3/envs/aws/lib/python3.8/site-packages/sagemaker/estimator.py in deploy(self, initial_instance_count, instance_type, serializer, deserializer, accelerator_type, endpoint_name, use_compiled_model, wait, model_name, kms_key, data_capture_config, tags, serverless_inference_config, async_inference_config, **kwargs)
#    1267         )
#    1268
# -> 1269         return model.deploy(
#    1270             instance_type=instance_type,
#    1271             initial_instance_count=initial_instance_count,
#
# ~/anaconda3/envs/aws/lib/python3.8/site-packages/sagemaker/model.py in deploy(self, initial_instance_count, instance_type, serializer, deserializer, accelerator_type, endpoint_name, tags, kms_key, wait, data_capture_config, async_inference_config, serverless_inference_config, **kwargs)
#    1075                 self._base_name = "-".join((self._base_name, compiled_model_suffix))
#    1076
# -> 1077         self._create_sagemaker_model(
#    1078             instance_type, accelerator_type, tags, serverless_inference_config
#    1079         )
#
# ~/anaconda3/envs/aws/lib/python3.8/site-packages/sagemaker/model.py in _create_sagemaker_model(self, instance_type, accelerator_type, tags, serverless_inference_config)
#     624             tags=tags,
#     625         )
# --> 626         self.sagemaker_session.create_model(**create_model_args)
#     627
#     628     def _ensure_base_name_if_needed(self, image_uri, script_uri, model_uri):
#
# ~/anaconda3/envs/aws/lib/python3.8/site-packages/sagemaker/session.py in create_model(self, name, role, container_defs, vpc_config, enable_network_isolation, primary_container, tags)
#    2697                     raise
#    2698
# -> 2699         self._intercept_create_request(create_model_request, submit, self.create_model.__name__)
#    2700         return name
#    2701
#
# ~/anaconda3/envs/aws/lib/python3.8/site-packages/sagemaker/session.py in _intercept_create_request(self, request, create, func_name)
#    4201             func_name (str): the name of the function needed intercepting
#    4202         """
# -> 4203         return create(request)
#    4204
#    4205
#
# ~/anaconda3/envs/aws/lib/python3.8/site-packages/sagemaker/session.py in submit(request)
#    2685             LOGGER.debug("CreateModel request: %s", json.dumps(request, indent=4))
#    2686             try:
# -> 2687                 self.sagemaker_client.create_model(**request)
#    2688             except ClientError as e:
#    2689                 error_code = e.response["Error"]["Code"]
#
# ~/anaconda3/envs/aws/lib/python3.8/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     506                 )
#     507             # The "self" in this scope is referring to the BaseClient.
# --> 508             return self._make_api_call(operation_name, kwargs)
#     509
#     510         _api_call.__name__ = str(py_operation_name)
#
# ~/anaconda3/envs/aws/lib/python3.8/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     909             error_code = parsed_response.get("Error", {}).get("Code")
#     910             error_class = self.exceptions.from_code(error_code)
# --> 911             raise error_class(parsed_response, operation_name)
#     912         else:
#     913             return parsed_response
#
# ClientError: An error occurred (ValidationException) when calling the CreateModel operation: Could not find model data at s3://sagemaker-us-west-2-976939723775/torch-hf-gpu-2022-06-14-01-2022-06-14-20-07-35-455/output/model.tar.gz.

# %% [markdown]
# When starting the training job, we need to let the sagemaker-training-toolkit library know where the sources are stored in Amazon S3 and what is the module to be invoked. These parameters are specified through the following reserved hyperparameters (these reserved hyperparameters are injected automatically when using framework estimators of the Amazon SageMaker Python SDK):
#
# sagemaker_program
# sagemaker_submit_directory
# Finally, we can execute the training job by calling the fit() method of the generic Estimator object defined in the Amazon SageMaker Python SDK (https://github.com/aws/sagemaker-python-sdk/blob/master/src/sagemaker/estimator.py). This corresponds to calling the CreateTrainingJob() API (https://docs.aws.amazon.com/sagemaker/latest/dg/API_CreateTrainingJob.html).

# %%
from sagemaker.estimator import Framework


class CustomFramework(Framework):
    def __init__(
        self,
        entry_point,
        source_dir=None,
        hyperparameters=None,
        py_version="py3",
        framework_version=None,
        image_name=None,
        distributions=None,
        **kwargs,
    ):
        super(CustomFramework, self).__init__(
            entry_point, source_dir, hyperparameters, image_name=image_name, **kwargs
        )

    def _configure_distribution(self, distributions):
        return

    def create_model(
        self,
        model_server_workers=None,
        role=None,
        vpc_config_override=None,
        entry_point=None,
        source_dir=None,
        dependencies=None,
        image_name=None,
        **kwargs,
    ):
        return None


import sagemaker

est_dyn = CustomFramework(
    image_name=container_image_uri,
    role=role,
    entry_point="train.py",
    source_dir="scripts/",
    train_instance_count=1,
    #train_instance_type="local",  # we use local mode
    train_instance_type='ml.m5.4xlarge',
    #base_job_name=prefix,
    hyperparameters=hyperparameters,
)
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# image_name has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %%
est_dyn.fit()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-68-3fb4a8407f64> in <module>
# ----> 1 est_dyn.fit()
#
# ~/anaconda3/envs/aws/lib/python3.8/site-packages/sagemaker/workflow/pipeline_context.py in wrapper(*args, **kwargs)
#     174             return self_instance.sagemaker_session.context
#     175
# --> 176         return run_func(*args, **kwargs)
#     177
#     178     return wrapper
#
# ~/anaconda3/envs/aws/lib/python3.8/site-packages/sagemaker/estimator.py in fit(self, inputs, wait, logs, job_name, experiment_config)
#     973                 * `TrialComponentDisplayName` is used for display in Studio.
#     974         """
# --> 975         self._prepare_for_training(job_name=job_name)
#     976
#     977         self.latest_training_job = _TrainingJob.start_new(self, inputs, experiment_config)
#
# ~/anaconda3/envs/aws/lib/python3.8/site-packages/sagemaker/estimator.py in _prepare_for_training(self, job_name)
#    2692                 constructor if applicable.
#    2693         """
# -> 2694         super(Framework, self)._prepare_for_training(job_name=job_name)
#    2695
#    2696         self._validate_and_set_debugger_configs()
#
# ~/anaconda3/envs/aws/lib/python3.8/site-packages/sagemaker/estimator.py in _prepare_for_training(self, job_name)
#     618                 constructor if applicable.
#     619         """
# --> 620         self._current_job_name = self._get_or_create_name(job_name)
#     621
#     622         # if output_path was specified we use it otherwise initialize here.
#
# ~/anaconda3/envs/aws/lib/python3.8/site-packages/sagemaker/estimator.py in _get_or_create_name(self, name)
#     592             return name
#     593
# --> 594         self._ensure_base_job_name()
#     595         return name_from_base(self.base_job_name)
#     596
#
# ~/anaconda3/envs/aws/lib/python3.8/site-packages/sagemaker/estimator.py in _ensure_base_job_name(self)
#     576             self.base_job_name
#     577             or get_jumpstart_base_name_if_jumpstart_model(self.source_dir, self.model_uri)
# --> 578             or base_name_from_image(self.training_image_uri())
#     579         )
#     580
#
# ~/anaconda3/envs/aws/lib/python3.8/site-packages/sagemaker/estimator.py in training_image_uri(self, region)
#    2842             region=region or self.sagemaker_session.boto_region_name,
#    2843             framework=self._framework_name,
# -> 2844             framework_version=self.framework_version,  # pylint: disable=no-member
#    2845             py_version=self.py_version,  # pylint: disable=no-member
#    2846             image_uri=self.image_uri,
#
# AttributeError: 'CustomFramework' object has no attribute 'framework_version'

# %% [markdown]
# ## Setup SageMaker environment
#
# _If you are going to use Sagemaker in a local environment. You need access to an IAM Role with the required permissions for Sagemaker. You can find [here](https://docs.aws.amazon.com/sagemaker/latest/dg/sagemaker-roles.html) more about it._

# %%
import logging
import transformers
import sagemaker

logger = logging.getLogger('__name__')
logger.setLevel(logging.DEBUG)
logger.addHandler(logging.StreamHandler())
logger.info(f'Using SageMaker version: {sagemaker.__version__}')
logger.info(f'Using Transfomer version: {transformers.__version__}')


sess = sagemaker.Session()
# sagemaker session bucket -> used for uploading data, models and logs
# sagemaker will automatically create this bucket if it not exists
sagemaker_session_bucket=None
if sagemaker_session_bucket is None and sess is not None:
    # set to default bucket if a bucket name is not given
    sagemaker_session_bucket = sess.default_bucket()

#role = sagemaker.get_execution_role()
role = 'arn:aws:iam::976939723775:role/service-role/AmazonSageMaker-ExecutionRole-20210317T133000'
sess = sagemaker.Session(default_bucket=sagemaker_session_bucket)

print(f"sagemaker role arn: {role}")
print(f"sagemaker bucket: {sess.default_bucket()}")
print(f"sagemaker session region: {sess.boto_region_name}")
# Out:
# Using SageMaker version: 2.92.1
# Using Transfomer version: 4.19.2
# sagemaker role arn: arn:aws:iam::976939723775:role/service-role/AmazonSageMaker-ExecutionRole-20210317T133000
# sagemaker bucket: sagemaker-us-west-2-976939723775
# sagemaker session region: us-west-2

# %% [markdown]
# Sagemaker is providing useful properties about the training environment through various environment variables, including the following:
#
# * `SM_MODEL_DIR`: A string that represents the path where the training job writes the model artifacts to. After training, artifacts in this directory are uploaded to S3 for model hosting.
#
# * `SM_NUM_GPUS`: An integer representing the number of GPUs available to the host.
#
# * `SM_CHANNEL_XXXX:` A string that represents the path to the directory that contains the input data for the specified channel. For example, if you specify two input channels in the HuggingFace estimator’s fit call, named `train` and `test`, the environment variables `SM_CHANNEL_TRAIN` and `SM_CHANNEL_TEST` are set.
#
#
# To run your training job locally you can define `instance_type='local'` or `instance_type='local_gpu'` for gpu usage. _Note: this does not working within SageMaker Studio_
#
# ## Creating an Estimator and start a training job
#
# In this example we are going to use the capability to download/use a fine-tuning script from a `git`- repository. We are using the `run_qa.py` from the `transformers` example scripts. You can find the code [here](https://github.com/huggingface/transformers/tree/master/examples/question-answering).
#
#
# ### RANK in MPI
#
# As to your question: processes are the actual instances of the program that are running. MPI allows you to create logical groups of processes, and in each group, a process is identified by its rank. This is an integer in the range [0, N-1] where N is the size of the group. Communicators are objects that handle communication between processes. An intra-communicator handles processes within a single group, while an inter-communicator handles communication between two distinct groups.
#
# By default, you have a single group that contains all your processes, and the intra-communicator MPI_COMM_WORLD that handles communication between them. This is sufficient for most applications, and does blur the distinction between process and rank a bit. The main thing to remember is that the rank of a process is always relative to a group. If you were to split your processes into two groups (e.g. one group to read input and another group to process data), then each process would now have two ranks: the one it originally had in MPI_COMM_WORLD, and one in its new group.

# %%
from transformers import AutoTokenizer

# tokenizer used in preprocessing
tokenizer_name = 'bert-large-uncased-whole-word-masking'
#tokenizer_name = 'roberta-large'

# download tokenizer
tokenizer = AutoTokenizer.from_pretrained(tokenizer_name)

# %%
from sagemaker.estimator import Estimator

# hyperparameters, which are passed into the training job
hyperparameters={
    'model_name_or_path': tokenizer_name,
    'dataset_name':'squad',
    'do_train': True,
    'do_eval': True,
    'fp16': True,
    'per_device_train_batch_size': 4,
    'per_device_eval_batch_size': 4,
    'num_train_epochs': 2,
    'max_seq_length': 384,
    'max_steps': 100,
    'pad_to_max_length': True,
    'doc_stride': 128,
    'output_dir': '/opt/ml/model',
}

# configuration for running training on smdistributed Data Parallel
dp_options = {
    "enabled":True,
    "custom_mpi_options": "-verbose -x NCCL_DEBUG=VERSION -x RANK=0 -x WORLD_SIZE=2",
    "parameters": {
        "microbatches": 4,
    }
}

# configuration for running training on smdistributed Data Parallel
distribution = {
    'smdistributed':{'dataparallel':dp_options}, 
    'parameter_server':{'enabled':False},
}


# git configuration to download our fine-tuning script
git_config = {'repo': 'https://github.com/huggingface/transformers.git','branch': 'v4.6.1'}
hub = {
    'HF_MODEL_ID':tokenizer_name,
    'SAGEMAKER_REQUIREMENTS': 'glue_requirements.txt', # path relative to `source_dir` below.
    'HF_TASK':'question-answering'
}
# instance configurations
instance_type='ml.p3.2xlarge'
instance_count=2 # if set 1 you might get "Environment variable SAGEMAKER_INSTANCE_TYPE is not set" error
volume_size=200


# metric definition to extract the results
metric_definitions=[
     {"Name": "train_runtime", "Regex": "train_runtime.*=\D*(.*?)$"},
     {'Name': 'train_samples_per_second', 'Regex': "train_samples_per_second.*=\D*(.*?)$"},
     {'Name': 'epoch', 'Regex': "epoch.*=\D*(.*?)$"},
     {'Name': 'f1', 'Regex': "f1.*=\D*(.*?)$"},
     {'Name': 'exact_match', 'Regex': "exact_match.*=\D*(.*?)$"}]

# %%
def json_encode_hyperparameters(hyperparameters):
    return {str(k): json.dumps(v) for (k, v) in hyperparameters.items()}

# %%
hyperparameters_json=json_encode_hyperparameters({
    'model_name_or_path': tokenizer_name,
    'dataset_name':'squad',
    'do_train': True,
    'do_eval': True,
    'fp16': True,
    'per_device_train_batch_size': 4,
    'per_device_eval_batch_size': 4,
    'num_train_epochs': 2,
    'max_seq_length': 384,
    'max_steps': 100,
    'pad_to_max_length': True,
    'doc_stride': 128,
    'output_dir': '/opt/ml/model',
})

# %%
account = !aws sts get-caller-identity --query Account --output text
algorithm_name='torch-hf-gpu-100'
ecr_image = '{}.dkr.ecr.{}.amazonaws.com/{}:latest'.format(account[0], sess.boto_region_name, algorithm_name)
print(ecr_image)
# Out:
# 976939723775.dkr.ecr.us-west-2.amazonaws.com/torch-hf-gpu-100:latest

# %%
job_name='torch-hf-gpu-2022-06-06-17-01'

# %%
# estimator
huggingface_estimator = Estimator(image_uri=ecr_image,
                                    #git_config=git_config,
                                    #env=hub,
                                    metric_definitions=metric_definitions,
                                    instance_type=instance_type,
                                    instance_count=instance_count,
                                    volume_size=volume_size,
                                    role=role,
                                    distribution= distribution,
                                    hyperparameters = hyperparameters_json)

# %%
# starting the train job
huggingface_estimator.fit(job_name=job_name)
# Out:
# 2022-06-15 15:26:57 Starting - Starting the training job...
# 2022-06-15 15:27:24 Starting - Preparing the instances for trainingProfilerReport-1655306817: InProgress
# .........
# 2022-06-15 15:28:57 Downloading - Downloading input data
# 2022-06-15 15:28:57 Training - Downloading the training image....................................
# 2022-06-15 15:34:44 Training - Training image download completed. Training in progress.bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2022-06-15 15:34:47,405 sagemaker-training-toolkit INFO     Imported framework sagemaker_pytorch_container.training
# 2022-06-15 15:34:47,425 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2022-06-15 15:34:47,433 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2022-06-15 15:34:47,498 sagemaker-training-toolkit INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {},
#     "current_host": "algo-2",
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1",
#         "algo-2"
#     ],
#     "hyperparameters": {
#         "dataset_name": "squad",
#         "do_eval": true,
#         "do_train": true,
#         "doc_stride": 128,
#         "fp16": true,
#         "max_seq_length": 384,
#         "max_steps": 100,
#         "model_name_or_path": "bert-large-uncased-whole-word-masking",
#         "num_train_epochs": 2,
#         "output_dir": "/opt/ml/model",
#         "pad_to_max_length": true,
#         "per_device_eval_batch_size": 4,
#         "per_device_train_batch_size": 4
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {},
#     "input_dir": "/opt/ml/input",
#     "is_master": false,
#     "job_name": "torch-hf-gpu-2022-06-06-17-01",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "/opt/ml/code",
#     "module_name": "/opt/ml/code/train",
#     "network_interface_name": "eth0",
#     "num_cpus": 8,
#     "num_gpus": 1,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-2",
#         "current_instance_type": "ml.p3.2xlarge",
#         "current_group_name": "homogeneousCluster",
#         "hosts": [
#             "algo-1",
#             "algo-2"
#         ],
#         "instance_groups": [
#             {
#                 "instance_group_name": "homogeneousCluster",
#                 "instance_type": "ml.p3.2xlarge",
#                 "hosts": [
#                     "algo-1",
#                     "algo-2"
#                 ]
#             }
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "/opt/ml/code/train.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1","algo-2"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"dataset_name":"squad","do_eval":true,"do_train":true,"doc_stride":128,"fp16":true,"max_seq_length":384,"max_steps":100,"model_name_or_path":"bert-large-uncased-whole-word-masking","num_train_epochs":2,"output_dir":"/opt/ml/model","pad_to_max_length":true,"per_device_eval_batch_size":4,"per_device_train_batch_size":4}
# SM_USER_ENTRY_POINT=/opt/ml/code/train.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_group_name":"homogeneousCluster","current_host":"algo-2","current_instance_type":"ml.p3.2xlarge","hosts":["algo-1","algo-2"],"instance_groups":[{"hosts":["algo-1","algo-2"],"instance_group_name":"homogeneousCluster","instance_type":"ml.p3.2xlarge"}],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=[]
# SM_CURRENT_HOST=algo-2
# SM_MODULE_NAME=/opt/ml/code/train
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=8
# SM_NUM_GPUS=1
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=/opt/ml/code
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{},"current_host":"algo-2","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1","algo-2"],"hyperparameters":{"dataset_name":"squad","do_eval":true,"do_train":true,"doc_stride":128,"fp16":true,"max_seq_length":384,"max_steps":100,"model_name_or_path":"bert-large-uncased-whole-word-masking","num_train_epochs":2,"output_dir":"/opt/ml/model","pad_to_max_length":true,"per_device_eval_batch_size":4,"per_device_train_batch_size":4},"input_config_dir":"/opt/ml/input/config","input_data_config":{},"input_dir":"/opt/ml/input","is_master":false,"job_name":"torch-hf-gpu-2022-06-06-17-01","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"/opt/ml/code","module_name":"/opt/ml/code/train","network_interface_name":"eth0","num_cpus":8,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_group_name":"homogeneousCluster","current_host":"algo-2","current_instance_type":"ml.p3.2xlarge","hosts":["algo-1","algo-2"],"instance_groups":[{"hosts":["algo-1","algo-2"],"instance_group_name":"homogeneousCluster","instance_type":"ml.p3.2xlarge"}],"network_interface_name":"eth0"},"user_entry_point":"/opt/ml/code/train.py"}
# SM_USER_ARGS=["--dataset_name","squad","--do_eval","True","--do_train","True","--doc_stride","128","--fp16","True","--max_seq_length","384","--max_steps","100","--model_name_or_path","bert-large-uncased-whole-word-masking","--num_train_epochs","2","--output_dir","/opt/ml/model","--pad_to_max_length","True","--per_device_eval_batch_size","4","--per_device_train_batch_size","4"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_HP_DATASET_NAME=squad
# SM_HP_DO_EVAL=true
# SM_HP_DO_TRAIN=true
# SM_HP_DOC_STRIDE=128
# SM_HP_FP16=true
# SM_HP_MAX_SEQ_LENGTH=384
# SM_HP_MAX_STEPS=100
# SM_HP_MODEL_NAME_OR_PATH=bert-large-uncased-whole-word-masking
# SM_HP_NUM_TRAIN_EPOCHS=2
# SM_HP_OUTPUT_DIR=/opt/ml/model
# SM_HP_PAD_TO_MAX_LENGTH=true
# SM_HP_PER_DEVICE_EVAL_BATCH_SIZE=4
# SM_HP_PER_DEVICE_TRAIN_BATCH_SIZE=4
# PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python38.zip:/opt/conda/lib/python3.8:/opt/conda/lib/python3.8/lib-dynload:/opt/conda/lib/python3.8/site-packages
# Invoking script with the following command:
# /opt/conda/bin/python3.8 /opt/ml/code/train.py --dataset_name squad --do_eval True --do_train True --doc_stride 128 --fp16 True --max_seq_length 384 --max_steps 100 --model_name_or_path bert-large-uncased-whole-word-masking --num_train_epochs 2 --output_dir /opt/ml/model --pad_to_max_length True --per_device_eval_batch_size 4 --per_device_train_batch_size 4
# bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2022-06-15 15:34:47,546 sagemaker-training-toolkit INFO     Imported framework sagemaker_pytorch_container.training
# 2022-06-15 15:34:47,567 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2022-06-15 15:34:47,576 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2022-06-15 15:34:47,641 sagemaker-training-toolkit INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {},
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1",
#         "algo-2"
#     ],
#     "hyperparameters": {
#         "dataset_name": "squad",
#         "do_eval": true,
#         "do_train": true,
#         "doc_stride": 128,
#         "fp16": true,
#         "max_seq_length": 384,
#         "max_steps": 100,
#         "model_name_or_path": "bert-large-uncased-whole-word-masking",
#         "num_train_epochs": 2,
#         "output_dir": "/opt/ml/model",
#         "pad_to_max_length": true,
#         "per_device_eval_batch_size": 4,
#         "per_device_train_batch_size": 4
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {},
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "torch-hf-gpu-2022-06-06-17-01",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "/opt/ml/code",
#     "module_name": "/opt/ml/code/train",
#     "network_interface_name": "eth0",
#     "num_cpus": 8,
#     "num_gpus": 1,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "current_instance_type": "ml.p3.2xlarge",
#         "current_group_name": "homogeneousCluster",
#         "hosts": [
#             "algo-1",
#             "algo-2"
#         ],
#         "instance_groups": [
#             {
#                 "instance_group_name": "homogeneousCluster",
#                 "instance_type": "ml.p3.2xlarge",
#                 "hosts": [
#                     "algo-1",
#                     "algo-2"
#                 ]
#             }
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "/opt/ml/code/train.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1","algo-2"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"dataset_name":"squad","do_eval":true,"do_train":true,"doc_stride":128,"fp16":true,"max_seq_length":384,"max_steps":100,"model_name_or_path":"bert-large-uncased-whole-word-masking","num_train_epochs":2,"output_dir":"/opt/ml/model","pad_to_max_length":true,"per_device_eval_batch_size":4,"per_device_train_batch_size":4}
# SM_USER_ENTRY_POINT=/opt/ml/code/train.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.p3.2xlarge","hosts":["algo-1","algo-2"],"instance_groups":[{"hosts":["algo-1","algo-2"],"instance_group_name":"homogeneousCluster","instance_type":"ml.p3.2xlarge"}],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=[]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=/opt/ml/code/train
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=8
# SM_NUM_GPUS=1
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=/opt/ml/code
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{},"current_host":"algo-1","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1","algo-2"],"hyperparameters":{"dataset_name":"squad","do_eval":true,"do_train":true,"doc_stride":128,"fp16":true,"max_seq_length":384,"max_steps":100,"model_name_or_path":"bert-large-uncased-whole-word-masking","num_train_epochs":2,"output_dir":"/opt/ml/model","pad_to_max_length":true,"per_device_eval_batch_size":4,"per_device_train_batch_size":4},"input_config_dir":"/opt/ml/input/config","input_data_config":{},"input_dir":"/opt/ml/input","is_master":true,"job_name":"torch-hf-gpu-2022-06-06-17-01","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"/opt/ml/code","module_name":"/opt/ml/code/train","network_interface_name":"eth0","num_cpus":8,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.p3.2xlarge","hosts":["algo-1","algo-2"],"instance_groups":[{"hosts":["algo-1","algo-2"],"instance_group_name":"homogeneousCluster","instance_type":"ml.p3.2xlarge"}],"network_interface_name":"eth0"},"user_entry_point":"/opt/ml/code/train.py"}
# SM_USER_ARGS=["--dataset_name","squad","--do_eval","True","--do_train","True","--doc_stride","128","--fp16","True","--max_seq_length","384","--max_steps","100","--model_name_or_path","bert-large-uncased-whole-word-masking","--num_train_epochs","2","--output_dir","/opt/ml/model","--pad_to_max_length","True","--per_device_eval_batch_size","4","--per_device_train_batch_size","4"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_HP_DATASET_NAME=squad
# SM_HP_DO_EVAL=true
# SM_HP_DO_TRAIN=true
# SM_HP_DOC_STRIDE=128
# SM_HP_FP16=true
# SM_HP_MAX_SEQ_LENGTH=384
# SM_HP_MAX_STEPS=100
# SM_HP_MODEL_NAME_OR_PATH=bert-large-uncased-whole-word-masking
# SM_HP_NUM_TRAIN_EPOCHS=2
# SM_HP_OUTPUT_DIR=/opt/ml/model
# SM_HP_PAD_TO_MAX_LENGTH=true
# SM_HP_PER_DEVICE_EVAL_BATCH_SIZE=4
# SM_HP_PER_DEVICE_TRAIN_BATCH_SIZE=4
# PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python38.zip:/opt/conda/lib/python3.8:/opt/conda/lib/python3.8/lib-dynload:/opt/conda/lib/python3.8/site-packages
# Invoking script with the following command:
# /opt/conda/bin/python3.8 /opt/ml/code/train.py --dataset_name squad --do_eval True --do_train True --doc_stride 128 --fp16 True --max_seq_length 384 --max_steps 100 --model_name_or_path bert-large-uncased-whole-word-masking --num_train_epochs 2 --output_dir /opt/ml/model --pad_to_max_length True --per_device_eval_batch_size 4 --per_device_train_batch_size 4
# 06/15/2022 15:34:52 - WARNING - __main__ - Process rank: -1, device: cuda:0, n_gpu: 1distributed training: False, 16-bits training: True
# 06/15/2022 15:34:52 - INFO - __main__ - Training/evaluation parameters TrainingArguments(
# _n_gpu=1,
# adafactor=False,
# adam_beta1=0.9,
# adam_beta2=0.999,
# adam_epsilon=1e-08,
# auto_find_batch_size=False,
# bf16=False,
# bf16_full_eval=False,
# data_seed=None,
# dataloader_drop_last=False,
# dataloader_num_workers=0,
# dataloader_pin_memory=True,
# ddp_bucket_cap_mb=None,
# ddp_find_unused_parameters=None,
# debug=[],
# deepspeed=None,
# disable_tqdm=False,
# do_eval=True,
# do_predict=False,
# do_train=True,
# eval_accumulation_steps=None,
# eval_delay=0,
# eval_steps=None,
# evaluation_strategy=IntervalStrategy.NO,
# fp16=True,
# fp16_backend=auto,
# fp16_full_eval=False,
# fp16_opt_level=O1,
# fsdp=[],
# fsdp_min_num_params=0,
# full_determinism=False,
# gradient_accumulation_steps=1,
# gradient_checkpointing=False,
# greater_is_better=None,
# group_by_length=False,
# half_precision_backend=auto,
# hub_model_id=None,
# hub_private_repo=False,
# hub_strategy=HubStrategy.EVERY_SAVE,
# hub_token=<HUB_TOKEN>,
# ignore_data_skip=False,
# include_inputs_for_metrics=False,
# label_names=None,
# label_smoothing_factor=0.0,
# learning_rate=5e-05,
# length_column_name=length,
# load_best_model_at_end=False,
# local_rank=-1,
# log_level=-1,
# log_level_replica=-1,
# log_on_each_node=True,
# logging_dir=/opt/ml/model/runs/Jun15_15-34-52_algo-2,
# logging_first_step=False,
# logging_nan_inf_filter=True,
# logging_steps=500,
# logging_strategy=IntervalStrategy.STEPS,
# lr_scheduler_type=SchedulerType.LINEAR,
# max_grad_norm=1.0,
# max_steps=100,
# metric_for_best_model=None,
# mp_parameters=,
# no_cuda=False,
# num_train_epochs=2.0,
# optim=OptimizerNames.ADAMW_HF,
# output_dir=/opt/ml/model,
# overwrite_output_dir=False,
# past_index=-1,
# per_device_eval_batch_size=4,
# per_device_train_batch_size=4,
# prediction_loss_only=False,
# push_to_hub=False,
# push_to_hub_model_id=None,
# push_to_hub_organization=None,
# push_to_hub_token=<PUSH_TO_HUB_TOKEN>,
# remove_unused_columns=True,
# report_to=[],
# resume_from_checkpoint=None,
# run_name=/opt/ml/model,
# save_on_each_node=False,
# save_steps=500,
# save_strategy=IntervalStrategy.STEPS,
# save_total_limit=None,
# seed=42,
# sharded_ddp=[],
# skip_memory_metrics=True,
# tf32=None,
# tpu_metrics_debug=False,
# tpu_num_cores=None,
# use_legacy_prediction_loop=False,
# warmup_ratio=0.0,
# warmup_steps=0,
# weight_decay=0.0,
# xpu_backend=None,
# )
# 06/15/2022 15:34:53 - WARNING - __main__ - Process rank: -1, device: cuda:0, n_gpu: 1distributed training: False, 16-bits training: True
# 06/15/2022 15:34:53 - INFO - __main__ - Training/evaluation parameters TrainingArguments(
# _n_gpu=1,
# adafactor=False,
# adam_beta1=0.9,
# adam_beta2=0.999,
# adam_epsilon=1e-08,
# auto_find_batch_size=False,
# bf16=False,
# bf16_full_eval=False,
# data_seed=None,
# dataloader_drop_last=False,
# dataloader_num_workers=0,
# dataloader_pin_memory=True,
# ddp_bucket_cap_mb=None,
# ddp_find_unused_parameters=None,
# debug=[],
# deepspeed=None,
# disable_tqdm=False,
# do_eval=True,
# do_predict=False,
# do_train=True,
# eval_accumulation_steps=None,
# eval_delay=0,
# eval_steps=None,
# evaluation_strategy=IntervalStrategy.NO,
# fp16=True,
# fp16_backend=auto,
# fp16_full_eval=False,
# fp16_opt_level=O1,
# fsdp=[],
# fsdp_min_num_params=0,
# full_determinism=False,
# gradient_accumulation_steps=1,
# gradient_checkpointing=False,
# greater_is_better=None,
# group_by_length=False,
# half_precision_backend=auto,
# hub_model_id=None,
# hub_private_repo=False,
# hub_strategy=HubStrategy.EVERY_SAVE,
# hub_token=<HUB_TOKEN>,
# ignore_data_skip=False,
# include_inputs_for_metrics=False,
# label_names=None,
# label_smoothing_factor=0.0,
# learning_rate=5e-05,
# length_column_name=length,
# load_best_model_at_end=False,
# local_rank=-1,
# log_level=-1,
# log_level_replica=-1,
# log_on_each_node=True,
# logging_dir=/opt/ml/model/runs/Jun15_15-34-53_algo-1,
# logging_first_step=False,
# logging_nan_inf_filter=True,
# logging_steps=500,
# logging_strategy=IntervalStrategy.STEPS,
# lr_scheduler_type=SchedulerType.LINEAR,
# max_grad_norm=1.0,
# max_steps=100,
# metric_for_best_model=None,
# mp_parameters=,
# no_cuda=False,
# num_train_epochs=2.0,
# optim=OptimizerNames.ADAMW_HF,
# output_dir=/opt/ml/model,
# overwrite_output_dir=False,
# past_index=-1,
# per_device_eval_batch_size=4,
# per_device_train_batch_size=4,
# prediction_loss_only=False,
# push_to_hub=False,
# push_to_hub_model_id=None,
# push_to_hub_organization=None,
# push_to_hub_token=<PUSH_TO_HUB_TOKEN>,
# remove_unused_columns=True,
# report_to=[],
# resume_from_checkpoint=None,
# run_name=/opt/ml/model,
# save_on_each_node=False,
# save_steps=500,
# save_strategy=IntervalStrategy.STEPS,
# save_total_limit=None,
# seed=42,
# sharded_ddp=[],
# skip_memory_metrics=True,
# tf32=None,
# tpu_metrics_debug=False,
# tpu_num_cores=None,
# use_legacy_prediction_loop=False,
# warmup_ratio=0.0,
# warmup_steps=0,
# weight_decay=0.0,
# xpu_backend=None,
# )
# 06/15/2022 15:34:53 - INFO - datasets.utils.file_utils - https://raw.githubusercontent.com/huggingface/datasets/2.2.0/datasets/squad/squad.py not found in cache or force_download set to True, downloading to /root/.cache/huggingface/datasets/downloads/tmpeo38f0li
# 06/15/2022 15:34:53 - INFO - datasets.utils.file_utils - storing https://raw.githubusercontent.com/huggingface/datasets/2.2.0/datasets/squad/squad.py in cache at /root/.cache/huggingface/datasets/downloads/e15e9c1bfb0ed35b5b3246f59d186eaf1f14c805071f0621390ea512017ba5fb.88910a81ad509b864eb2728ed18e25076f86eaa3cd11c5587ab5ceea8903a4bc.py
# 06/15/2022 15:34:53 - INFO - datasets.utils.file_utils - creating metadata file for /root/.cache/huggingface/datasets/downloads/e15e9c1bfb0ed35b5b3246f59d186eaf1f14c805071f0621390ea512017ba5fb.88910a81ad509b864eb2728ed18e25076f86eaa3cd11c5587ab5ceea8903a4bc.py
# 06/15/2022 15:34:53 - INFO - datasets.utils.file_utils - https://raw.githubusercontent.com/huggingface/datasets/2.2.0/datasets/squad/dataset_infos.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/datasets/downloads/tmpmsa7la0h
# 06/15/2022 15:34:53 - INFO - datasets.utils.file_utils - storing https://raw.githubusercontent.com/huggingface/datasets/2.2.0/datasets/squad/dataset_infos.json in cache at /root/.cache/huggingface/datasets/downloads/0da665d7074d4a9486d6f562de7b42cf00044998da41f25685e6b2de047fa5fa.36bd0df82ceb24eeafc05394b25c534952fd7b2eaacf2b1f49933a8330f5800b
# 06/15/2022 15:34:53 - INFO - datasets.utils.file_utils - creating metadata file for /root/.cache/huggingface/datasets/downloads/0da665d7074d4a9486d6f562de7b42cf00044998da41f25685e6b2de047fa5fa.36bd0df82ceb24eeafc05394b25c534952fd7b2eaacf2b1f49933a8330f5800b
# 06/15/2022 15:34:53 - INFO - datasets.builder - No config specified, defaulting to the single config: squad/plain_text
# 06/15/2022 15:34:53 - INFO - datasets.info - Loading Dataset Infos from /root/.cache/huggingface/modules/datasets_modules/datasets/squad/d6ec3ceb99ca480ce37cdd35555d6cb2511d223b9150cce08a837ef62ffea453
# 06/15/2022 15:34:53 - INFO - datasets.builder - Generating dataset squad (/root/.cache/huggingface/datasets/squad/plain_text/1.0.0/d6ec3ceb99ca480ce37cdd35555d6cb2511d223b9150cce08a837ef62ffea453)
# Downloading and preparing dataset squad/plain_text (download: 33.51 MiB, generated: 85.63 MiB, post-processed: Unknown size, total: 119.14 MiB) to /root/.cache/huggingface/datasets/squad/plain_text/1.0.0/d6ec3ceb99ca480ce37cdd35555d6cb2511d223b9150cce08a837ef62ffea453...
# 06/15/2022 15:34:53 - INFO - datasets.builder - Dataset not on Hf google storage. Downloading and preparing it from source
# 06/15/2022 15:34:54 - INFO - datasets.utils.file_utils - https://raw.githubusercontent.com/huggingface/datasets/2.2.0/datasets/squad/squad.py not found in cache or force_download set to True, downloading to /root/.cache/huggingface/datasets/downloads/tmpnlht18gh
# 06/15/2022 15:34:54 - INFO - datasets.utils.file_utils - storing https://raw.githubusercontent.com/huggingface/datasets/2.2.0/datasets/squad/squad.py in cache at /root/.cache/huggingface/datasets/downloads/e15e9c1bfb0ed35b5b3246f59d186eaf1f14c805071f0621390ea512017ba5fb.88910a81ad509b864eb2728ed18e25076f86eaa3cd11c5587ab5ceea8903a4bc.py
# 06/15/2022 15:34:54 - INFO - datasets.utils.file_utils - creating metadata file for /root/.cache/huggingface/datasets/downloads/e15e9c1bfb0ed35b5b3246f59d186eaf1f14c805071f0621390ea512017ba5fb.88910a81ad509b864eb2728ed18e25076f86eaa3cd11c5587ab5ceea8903a4bc.py
# 06/15/2022 15:34:54 - INFO - datasets.utils.file_utils - https://raw.githubusercontent.com/huggingface/datasets/2.2.0/datasets/squad/dataset_infos.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/datasets/downloads/tmpbcupkfz4
# 06/15/2022 15:34:54 - INFO - datasets.utils.file_utils - storing https://raw.githubusercontent.com/huggingface/datasets/2.2.0/datasets/squad/dataset_infos.json in cache at /root/.cache/huggingface/datasets/downloads/0da665d7074d4a9486d6f562de7b42cf00044998da41f25685e6b2de047fa5fa.36bd0df82ceb24eeafc05394b25c534952fd7b2eaacf2b1f49933a8330f5800b
# 06/15/2022 15:34:54 - INFO - datasets.utils.file_utils - creating metadata file for /root/.cache/huggingface/datasets/downloads/0da665d7074d4a9486d6f562de7b42cf00044998da41f25685e6b2de047fa5fa.36bd0df82ceb24eeafc05394b25c534952fd7b2eaacf2b1f49933a8330f5800b
# 06/15/2022 15:34:54 - INFO - datasets.builder - No config specified, defaulting to the single config: squad/plain_text
# 06/15/2022 15:34:54 - INFO - datasets.info - Loading Dataset Infos from /root/.cache/huggingface/modules/datasets_modules/datasets/squad/d6ec3ceb99ca480ce37cdd35555d6cb2511d223b9150cce08a837ef62ffea453
# 06/15/2022 15:34:54 - INFO - datasets.builder - Generating dataset squad (/root/.cache/huggingface/datasets/squad/plain_text/1.0.0/d6ec3ceb99ca480ce37cdd35555d6cb2511d223b9150cce08a837ef62ffea453)
# Downloading and preparing dataset squad/plain_text (download: 33.51 MiB, generated: 85.63 MiB, post-processed: Unknown size, total: 119.14 MiB) to /root/.cache/huggingface/datasets/squad/plain_text/1.0.0/d6ec3ceb99ca480ce37cdd35555d6cb2511d223b9150cce08a837ef62ffea453...
# 06/15/2022 15:34:54 - INFO - datasets.builder - Dataset not on Hf google storage. Downloading and preparing it from source
# 06/15/2022 15:34:54 - INFO - datasets.utils.file_utils - https://rajpurkar.github.io/SQuAD-explorer/dataset/train-v1.1.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/datasets/downloads/tmp1rcto660
# 06/15/2022 15:34:54 - INFO - datasets.utils.file_utils - https://rajpurkar.github.io/SQuAD-explorer/dataset/train-v1.1.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/datasets/downloads/tmp9ttwhe0z
# 06/15/2022 15:34:55 - INFO - datasets.utils.file_utils - storing https://rajpurkar.github.io/SQuAD-explorer/dataset/train-v1.1.json in cache at /root/.cache/huggingface/datasets/downloads/b8bb19735e1bb591510a01cc032f4c9f969bc0eeb081ae1b328cd306f3b24008
# 06/15/2022 15:34:55 - INFO - datasets.utils.file_utils - creating metadata file for /root/.cache/huggingface/datasets/downloads/b8bb19735e1bb591510a01cc032f4c9f969bc0eeb081ae1b328cd306f3b24008
# 06/15/2022 15:34:55 - INFO - datasets.utils.file_utils - storing https://rajpurkar.github.io/SQuAD-explorer/dataset/train-v1.1.json in cache at /root/.cache/huggingface/datasets/downloads/b8bb19735e1bb591510a01cc032f4c9f969bc0eeb081ae1b328cd306f3b24008
# 06/15/2022 15:34:55 - INFO - datasets.utils.file_utils - creating metadata file for /root/.cache/huggingface/datasets/downloads/b8bb19735e1bb591510a01cc032f4c9f969bc0eeb081ae1b328cd306f3b24008
# 06/15/2022 15:34:55 - INFO - datasets.utils.file_utils - https://rajpurkar.github.io/SQuAD-explorer/dataset/dev-v1.1.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/datasets/downloads/tmph3qcj8g3
# 06/15/2022 15:34:55 - INFO - datasets.utils.file_utils - storing https://rajpurkar.github.io/SQuAD-explorer/dataset/dev-v1.1.json in cache at /root/.cache/huggingface/datasets/downloads/9d5462987ef5f814fe15a369c1724f6ec39a2018b3b6271a9d7d2598686ca2ff
# 06/15/2022 15:34:55 - INFO - datasets.utils.file_utils - creating metadata file for /root/.cache/huggingface/datasets/downloads/9d5462987ef5f814fe15a369c1724f6ec39a2018b3b6271a9d7d2598686ca2ff
# 06/15/2022 15:34:55 - INFO - datasets.utils.download_manager - Downloading took 0.0 min
# 06/15/2022 15:34:55 - INFO - datasets.utils.download_manager - Checksum Computation took 0.0 min
# 06/15/2022 15:34:55 - INFO - datasets.utils.info_utils - All the checksums matched successfully for dataset source files
# 06/15/2022 15:34:55 - INFO - datasets.builder - Generating train split
# 06/15/2022 15:34:55 - INFO - datasets.utils.file_utils - https://rajpurkar.github.io/SQuAD-explorer/dataset/dev-v1.1.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/datasets/downloads/tmprpclvu1d
# 06/15/2022 15:34:55 - INFO - datasets.utils.file_utils - storing https://rajpurkar.github.io/SQuAD-explorer/dataset/dev-v1.1.json in cache at /root/.cache/huggingface/datasets/downloads/9d5462987ef5f814fe15a369c1724f6ec39a2018b3b6271a9d7d2598686ca2ff
# 06/15/2022 15:34:55 - INFO - datasets.utils.file_utils - creating metadata file for /root/.cache/huggingface/datasets/downloads/9d5462987ef5f814fe15a369c1724f6ec39a2018b3b6271a9d7d2598686ca2ff
# 06/15/2022 15:34:55 - INFO - datasets.utils.download_manager - Downloading took 0.0 min
# 06/15/2022 15:34:55 - INFO - datasets.utils.download_manager - Checksum Computation took 0.0 min
# 06/15/2022 15:34:55 - INFO - datasets.utils.info_utils - All the checksums matched successfully for dataset source files
# 06/15/2022 15:34:55 - INFO - datasets.builder - Generating train split
# 06/15/2022 15:35:03 - INFO - datasets.builder - Generating validation split
# 06/15/2022 15:35:03 - INFO - datasets.builder - Generating validation split
# 06/15/2022 15:35:03 - INFO - datasets.utils.info_utils - All the splits matched successfully.
# Dataset squad downloaded and prepared to /root/.cache/huggingface/datasets/squad/plain_text/1.0.0/d6ec3ceb99ca480ce37cdd35555d6cb2511d223b9150cce08a837ef62ffea453. Subsequent calls will reuse this data.
# [INFO|hub.py:583] 2022-06-15 15:35:04,299 >> https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/config.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmp8ddd_zeg
# 06/15/2022 15:35:04 - INFO - datasets.utils.info_utils - All the splits matched successfully.
# Dataset squad downloaded and prepared to /root/.cache/huggingface/datasets/squad/plain_text/1.0.0/d6ec3ceb99ca480ce37cdd35555d6cb2511d223b9150cce08a837ef62ffea453. Subsequent calls will reuse this data.
# [INFO|hub.py:583] 2022-06-15 15:35:04,402 >> https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/config.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmp9mcjcpsc
# [INFO|hub.py:587] 2022-06-15 15:35:04,686 >> storing https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/config.json in cache at /root/.cache/huggingface/transformers/86b0883704d931817042e5c354032897e1dd6ccd5c2260bf0f6d4a15a6e5a232.d4d29047141693194a1c377423a9a58b3ffdd39ed177b3a9b2ac9bce9e6638d9
# [INFO|hub.py:595] 2022-06-15 15:35:04,687 >> creating metadata file for /root/.cache/huggingface/transformers/86b0883704d931817042e5c354032897e1dd6ccd5c2260bf0f6d4a15a6e5a232.d4d29047141693194a1c377423a9a58b3ffdd39ed177b3a9b2ac9bce9e6638d9
# [INFO|configuration_utils.py:659] 2022-06-15 15:35:04,687 >> loading configuration file https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/86b0883704d931817042e5c354032897e1dd6ccd5c2260bf0f6d4a15a6e5a232.d4d29047141693194a1c377423a9a58b3ffdd39ed177b3a9b2ac9bce9e6638d9
# [INFO|configuration_utils.py:708] 2022-06-15 15:35:04,689 >> Model config BertConfig {
#   "_name_or_path": "bert-large-uncased-whole-word-masking",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.19.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
# [INFO|hub.py:587] 2022-06-15 15:35:04,596 >> storing https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/config.json in cache at /root/.cache/huggingface/transformers/86b0883704d931817042e5c354032897e1dd6ccd5c2260bf0f6d4a15a6e5a232.d4d29047141693194a1c377423a9a58b3ffdd39ed177b3a9b2ac9bce9e6638d9
# [INFO|hub.py:595] 2022-06-15 15:35:04,596 >> creating metadata file for /root/.cache/huggingface/transformers/86b0883704d931817042e5c354032897e1dd6ccd5c2260bf0f6d4a15a6e5a232.d4d29047141693194a1c377423a9a58b3ffdd39ed177b3a9b2ac9bce9e6638d9
# [INFO|configuration_utils.py:659] 2022-06-15 15:35:04,597 >> loading configuration file https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/86b0883704d931817042e5c354032897e1dd6ccd5c2260bf0f6d4a15a6e5a232.d4d29047141693194a1c377423a9a58b3ffdd39ed177b3a9b2ac9bce9e6638d9
# [INFO|configuration_utils.py:708] 2022-06-15 15:35:04,598 >> Model config BertConfig {
#   "_name_or_path": "bert-large-uncased-whole-word-masking",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.19.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
# [INFO|hub.py:583] 2022-06-15 15:35:04,904 >> https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/tokenizer_config.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpvmwvs3n3
# [INFO|hub.py:587] 2022-06-15 15:35:05,219 >> storing https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/tokenizer_config.json in cache at /root/.cache/huggingface/transformers/2a60ba33fe418e6652d2e5a6a40b189b0d6ca8a6a89e32a22bb5caf8d95982fe.20430bd8e10ef77a7d2977accefe796051e01bc2fc4aa146bc862997a1a15e79
# [INFO|hub.py:595] 2022-06-15 15:35:05,219 >> creating metadata file for /root/.cache/huggingface/transformers/2a60ba33fe418e6652d2e5a6a40b189b0d6ca8a6a89e32a22bb5caf8d95982fe.20430bd8e10ef77a7d2977accefe796051e01bc2fc4aa146bc862997a1a15e79
# [INFO|hub.py:583] 2022-06-15 15:35:04,977 >> https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/tokenizer_config.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmp799u1rum
# [INFO|hub.py:587] 2022-06-15 15:35:05,263 >> storing https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/tokenizer_config.json in cache at /root/.cache/huggingface/transformers/2a60ba33fe418e6652d2e5a6a40b189b0d6ca8a6a89e32a22bb5caf8d95982fe.20430bd8e10ef77a7d2977accefe796051e01bc2fc4aa146bc862997a1a15e79
# [INFO|hub.py:595] 2022-06-15 15:35:05,263 >> creating metadata file for /root/.cache/huggingface/transformers/2a60ba33fe418e6652d2e5a6a40b189b0d6ca8a6a89e32a22bb5caf8d95982fe.20430bd8e10ef77a7d2977accefe796051e01bc2fc4aa146bc862997a1a15e79
# [INFO|configuration_utils.py:659] 2022-06-15 15:35:05,547 >> loading configuration file https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/86b0883704d931817042e5c354032897e1dd6ccd5c2260bf0f6d4a15a6e5a232.d4d29047141693194a1c377423a9a58b3ffdd39ed177b3a9b2ac9bce9e6638d9
# [INFO|configuration_utils.py:708] 2022-06-15 15:35:05,548 >> Model config BertConfig {
#   "_name_or_path": "bert-large-uncased-whole-word-masking",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.19.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
# [INFO|configuration_utils.py:659] 2022-06-15 15:35:05,528 >> loading configuration file https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/86b0883704d931817042e5c354032897e1dd6ccd5c2260bf0f6d4a15a6e5a232.d4d29047141693194a1c377423a9a58b3ffdd39ed177b3a9b2ac9bce9e6638d9
# [INFO|configuration_utils.py:708] 2022-06-15 15:35:05,529 >> Model config BertConfig {
#   "_name_or_path": "bert-large-uncased-whole-word-masking",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.19.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
# [INFO|hub.py:583] 2022-06-15 15:35:06,138 >> https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/vocab.txt not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpoizenute
# [INFO|hub.py:583] 2022-06-15 15:35:06,126 >> https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/vocab.txt not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmp7u2g89q0
# [INFO|hub.py:587] 2022-06-15 15:35:06,641 >> storing https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/vocab.txt in cache at /root/.cache/huggingface/transformers/b6fcd4f8304ce7ce4a5462db5a53616f8464a083bbe20508ea92d5e07229086f.d789d64ebfe299b0e416afc4a169632f903f693095b4629a7ea271d5a0cf2c99
# [INFO|hub.py:595] 2022-06-15 15:35:06,642 >> creating metadata file for /root/.cache/huggingface/transformers/b6fcd4f8304ce7ce4a5462db5a53616f8464a083bbe20508ea92d5e07229086f.d789d64ebfe299b0e416afc4a169632f903f693095b4629a7ea271d5a0cf2c99
# [INFO|hub.py:587] 2022-06-15 15:35:06,706 >> storing https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/vocab.txt in cache at /root/.cache/huggingface/transformers/b6fcd4f8304ce7ce4a5462db5a53616f8464a083bbe20508ea92d5e07229086f.d789d64ebfe299b0e416afc4a169632f903f693095b4629a7ea271d5a0cf2c99
# [INFO|hub.py:595] 2022-06-15 15:35:06,707 >> creating metadata file for /root/.cache/huggingface/transformers/b6fcd4f8304ce7ce4a5462db5a53616f8464a083bbe20508ea92d5e07229086f.d789d64ebfe299b0e416afc4a169632f903f693095b4629a7ea271d5a0cf2c99
# [INFO|hub.py:583] 2022-06-15 15:35:07,012 >> https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/tokenizer.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpju8vzcqx
# [INFO|hub.py:583] 2022-06-15 15:35:06,933 >> https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/tokenizer.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmp9y_s0kb2
# [INFO|hub.py:587] 2022-06-15 15:35:07,545 >> storing https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/tokenizer.json in cache at /root/.cache/huggingface/transformers/33ee0bae279476c742373ecfd5a127d27372fbb9e2f5a84ccb38bbd72775f296.7f2721073f19841be16f41b0a70b600ca6b880c8f3df6f3535cbc704371bdfa4
# [INFO|hub.py:595] 2022-06-15 15:35:07,545 >> creating metadata file for /root/.cache/huggingface/transformers/33ee0bae279476c742373ecfd5a127d27372fbb9e2f5a84ccb38bbd72775f296.7f2721073f19841be16f41b0a70b600ca6b880c8f3df6f3535cbc704371bdfa4
# [INFO|hub.py:587] 2022-06-15 15:35:07,647 >> storing https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/tokenizer.json in cache at /root/.cache/huggingface/transformers/33ee0bae279476c742373ecfd5a127d27372fbb9e2f5a84ccb38bbd72775f296.7f2721073f19841be16f41b0a70b600ca6b880c8f3df6f3535cbc704371bdfa4
# [INFO|hub.py:595] 2022-06-15 15:35:07,648 >> creating metadata file for /root/.cache/huggingface/transformers/33ee0bae279476c742373ecfd5a127d27372fbb9e2f5a84ccb38bbd72775f296.7f2721073f19841be16f41b0a70b600ca6b880c8f3df6f3535cbc704371bdfa4
# [INFO|tokenization_utils_base.py:1782] 2022-06-15 15:35:08,395 >> loading file https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/vocab.txt from cache at /root/.cache/huggingface/transformers/b6fcd4f8304ce7ce4a5462db5a53616f8464a083bbe20508ea92d5e07229086f.d789d64ebfe299b0e416afc4a169632f903f693095b4629a7ea271d5a0cf2c99
# [INFO|tokenization_utils_base.py:1782] 2022-06-15 15:35:08,396 >> loading file https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/tokenizer.json from cache at /root/.cache/huggingface/transformers/33ee0bae279476c742373ecfd5a127d27372fbb9e2f5a84ccb38bbd72775f296.7f2721073f19841be16f41b0a70b600ca6b880c8f3df6f3535cbc704371bdfa4
# [INFO|tokenization_utils_base.py:1782] 2022-06-15 15:35:08,396 >> loading file https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/added_tokens.json from cache at None
# [INFO|tokenization_utils_base.py:1782] 2022-06-15 15:35:08,396 >> loading file https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/special_tokens_map.json from cache at None
# [INFO|tokenization_utils_base.py:1782] 2022-06-15 15:35:08,396 >> loading file https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/tokenizer_config.json from cache at /root/.cache/huggingface/transformers/2a60ba33fe418e6652d2e5a6a40b189b0d6ca8a6a89e32a22bb5caf8d95982fe.20430bd8e10ef77a7d2977accefe796051e01bc2fc4aa146bc862997a1a15e79
# [INFO|configuration_utils.py:659] 2022-06-15 15:35:08,681 >> loading configuration file https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/86b0883704d931817042e5c354032897e1dd6ccd5c2260bf0f6d4a15a6e5a232.d4d29047141693194a1c377423a9a58b3ffdd39ed177b3a9b2ac9bce9e6638d9
# [INFO|configuration_utils.py:708] 2022-06-15 15:35:08,682 >> Model config BertConfig {
#   "_name_or_path": "bert-large-uncased-whole-word-masking",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.19.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
# [INFO|tokenization_utils_base.py:1782] 2022-06-15 15:35:08,567 >> loading file https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/vocab.txt from cache at /root/.cache/huggingface/transformers/b6fcd4f8304ce7ce4a5462db5a53616f8464a083bbe20508ea92d5e07229086f.d789d64ebfe299b0e416afc4a169632f903f693095b4629a7ea271d5a0cf2c99
# [INFO|tokenization_utils_base.py:1782] 2022-06-15 15:35:08,567 >> loading file https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/tokenizer.json from cache at /root/.cache/huggingface/transformers/33ee0bae279476c742373ecfd5a127d27372fbb9e2f5a84ccb38bbd72775f296.7f2721073f19841be16f41b0a70b600ca6b880c8f3df6f3535cbc704371bdfa4
# [INFO|tokenization_utils_base.py:1782] 2022-06-15 15:35:08,568 >> loading file https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/added_tokens.json from cache at None
# [INFO|tokenization_utils_base.py:1782] 2022-06-15 15:35:08,568 >> loading file https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/special_tokens_map.json from cache at None
# [INFO|tokenization_utils_base.py:1782] 2022-06-15 15:35:08,568 >> loading file https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/tokenizer_config.json from cache at /root/.cache/huggingface/transformers/2a60ba33fe418e6652d2e5a6a40b189b0d6ca8a6a89e32a22bb5caf8d95982fe.20430bd8e10ef77a7d2977accefe796051e01bc2fc4aa146bc862997a1a15e79
# [INFO|configuration_utils.py:659] 2022-06-15 15:35:08,864 >> loading configuration file https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/86b0883704d931817042e5c354032897e1dd6ccd5c2260bf0f6d4a15a6e5a232.d4d29047141693194a1c377423a9a58b3ffdd39ed177b3a9b2ac9bce9e6638d9
# [INFO|configuration_utils.py:708] 2022-06-15 15:35:08,864 >> Model config BertConfig {
#   "_name_or_path": "bert-large-uncased-whole-word-masking",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.19.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
# [INFO|hub.py:583] 2022-06-15 15:35:09,225 >> https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/pytorch_model.bin not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmp0476tjgg
# [INFO|hub.py:583] 2022-06-15 15:35:09,078 >> https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/pytorch_model.bin not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmptdn5cfc_
# [INFO|hub.py:587] 2022-06-15 15:35:35,952 >> storing https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/pytorch_model.bin in cache at /root/.cache/huggingface/transformers/fd59edc8ee9750d18ad7f5c4d97b4040bddfb6ccd64c37c421ffae14656dc51c.0bf22e1ed76b044bda5c02e02fdfc0bdf5a6e1827e76950cc9f43e1919ad896f
# [INFO|hub.py:595] 2022-06-15 15:35:35,952 >> creating metadata file for /root/.cache/huggingface/transformers/fd59edc8ee9750d18ad7f5c4d97b4040bddfb6ccd64c37c421ffae14656dc51c.0bf22e1ed76b044bda5c02e02fdfc0bdf5a6e1827e76950cc9f43e1919ad896f
# [INFO|modeling_utils.py:1953] 2022-06-15 15:35:35,953 >> loading weights file https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/pytorch_model.bin from cache at /root/.cache/huggingface/transformers/fd59edc8ee9750d18ad7f5c4d97b4040bddfb6ccd64c37c421ffae14656dc51c.0bf22e1ed76b044bda5c02e02fdfc0bdf5a6e1827e76950cc9f43e1919ad896f
# [INFO|hub.py:587] 2022-06-15 15:35:35,942 >> storing https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/pytorch_model.bin in cache at /root/.cache/huggingface/transformers/fd59edc8ee9750d18ad7f5c4d97b4040bddfb6ccd64c37c421ffae14656dc51c.0bf22e1ed76b044bda5c02e02fdfc0bdf5a6e1827e76950cc9f43e1919ad896f
# [INFO|hub.py:595] 2022-06-15 15:35:35,942 >> creating metadata file for /root/.cache/huggingface/transformers/fd59edc8ee9750d18ad7f5c4d97b4040bddfb6ccd64c37c421ffae14656dc51c.0bf22e1ed76b044bda5c02e02fdfc0bdf5a6e1827e76950cc9f43e1919ad896f
# [INFO|modeling_utils.py:1953] 2022-06-15 15:35:35,942 >> loading weights file https://huggingface.co/bert-large-uncased-whole-word-masking/resolve/main/pytorch_model.bin from cache at /root/.cache/huggingface/transformers/fd59edc8ee9750d18ad7f5c4d97b4040bddfb6ccd64c37c421ffae14656dc51c.0bf22e1ed76b044bda5c02e02fdfc0bdf5a6e1827e76950cc9f43e1919ad896f
# [WARNING|modeling_utils.py:2254] 2022-06-15 15:35:41,148 >> Some weights of the model checkpoint at bert-large-uncased-whole-word-masking were not used when initializing BertForQuestionAnswering: ['cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# [WARNING|modeling_utils.py:2265] 2022-06-15 15:35:41,149 >> Some weights of BertForQuestionAnswering were not initialized from the model checkpoint at bert-large-uncased-whole-word-masking and are newly initialized: ['qa_outputs.weight', 'qa_outputs.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [WARNING|modeling_utils.py:2254] 2022-06-15 15:35:41,122 >> Some weights of the model checkpoint at bert-large-uncased-whole-word-masking were not used when initializing BertForQuestionAnswering: ['cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing BertForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...
# #015 19%|█▉        | 1989/10570 [00:05<00:25, 342.37it/s]#033[A
# #015 19%|█▉        | 2024/10570 [00:05<00:26, 326.54it/s]#033[A
# #015 20%|█▉        | 2062/10570 [00:05<00:25, 339.15it/s]#033[A
# #015 20%|█▉        | 2098/10570 [00:05<00:24, 344.81it/s]#033[A
# #015 20%|██        | 2133/10570 [00:06<00:26, 321.27it/s]#033[A
# #015 21%|██        | 2170/10570 [00:06<00:25, 333.01it/s]#033[A
# #015 21%|██        | 2207/10570 [00:06<00:24, 341.66it/s]#033[A
# #015 21%|██        | 2242/10570 [00:06<00:24, 340.32it/s]#033[A
# #015 22%|██▏       | 2277/10570 [00:06<00:25, 324.97it/s]#033[A
# #015 22%|██▏       | 2310/10570 [00:06<00:25, 318.07it/s]#033[A
# #015 22%|██▏       | 2342/10570 [00:06<00:26, 311.13it/s]#033[A#015100%|██████████| 2696/2696 [02:46<00:00, 19.02it/s]
# #015 22%|██▏       | 2376/10570 [00:06<00:25, 317.13it/s]#033[A
# #015 23%|██▎       | 2411/10570 [00:06<00:25, 324.86it/s]#033[A
# #015 23%|██▎       | 2447/10570 [00:07<00:24, 334.50it/s]#033[A
# #015 24%|██▎       | 2484/10570 [00:07<00:23, 342.83it/s]#033[A
# #015 24%|██▍       | 2519/10570 [00:07<00:24, 327.75it/s]#033[A
# #015 24%|██▍       | 2553/10570 [00:07<00:24, 329.20it/s]#033[A
# #015 24%|██▍       | 2587/10570 [00:07<00:24, 331.69it/s]#033[A
# #015 25%|██▍       | 2625/10570 [00:07<00:23, 345.10it/s]#033[A
# #015 25%|██▌       | 2663/10570 [00:07<00:22, 354.14it/s]#033[A
# #015 26%|██▌       | 2700/10570 [00:07<00:22, 356.62it/s]#033[A
# #015 26%|██▌       | 2738/10570 [00:07<00:21, 363.32it/s]#033[A
# #015 26%|██▋       | 2775/10570 [00:07<00:21, 362.82it/s]#033[A
# #015 27%|██▋       | 2814/10570 [00:08<00:20, 369.55it/s]#033[A
# #015 27%|██▋       | 2851/10570 [00:08<00:21, 366.67it/s]#033[A
# #015 27%|██▋       | 2888/10570 [00:08<00:21, 362.38it/s]#033[A
# #015 28%|██▊       | 2925/10570 [00:08<00:21, 363.66it/s]#033[A
# #015 28%|██▊       | 2962/10570 [00:08<00:20, 364.93it/s]#033[A
# #015 28%|██▊       | 2999/10570 [00:08<00:20, 363.84it/s]#033[A
# #015 29%|██▊       | 3037/10570 [00:08<00:20, 367.58it/s]#033[A
# #015 29%|██▉       | 3074/10570 [00:08<00:20, 360.01it/s]#033[A
# #015 29%|██▉       | 3111/10570 [00:08<00:20, 358.62it/s]#033[A
# #015 30%|██▉       | 3147/10570 [00:08<00:20, 353.98it/s]#033[A
# #015 30%|███       | 3183/10570 [00:09<00:21, 351.00it/s]#033[A
# #015 30%|███       | 3219/10570 [00:09<00:20, 352.08it/s]#033[A
# #015 31%|███       | 3255/10570 [00:09<00:21, 348.21it/s]#033[A
# #015 31%|███       | 3291/10570 [00:09<00:20, 350.49it/s]#033[A
# #015 31%|███▏      | 3327/10570 [00:09<00:20, 351.37it/s]#033[A
# #015 32%|███▏      | 3364/10570 [00:09<00:20, 354.99it/s]#033[A
# #015 32%|███▏      | 3400/10570 [00:09<00:20, 354.56it/s]#033[A
# #015 33%|███▎      | 3436/10570 [00:09<00:20, 352.27it/s]#033[A
# #015 33%|███▎      | 3472/10570 [00:09<00:20, 354.14it/s]#033[A
# #015 33%|███▎      | 3508/10570 [00:09<00:20, 350.67it/s]#033[A
# #015 34%|███▎      | 3546/10570 [00:10<00:19, 356.96it/s]#033[A
# #015 34%|███▍      | 3582/10570 [00:10<00:19, 353.29it/s]#033[A
# #015 34%|███▍      | 3618/10570 [00:10<00:19, 353.05it/s]#033[A
# #015 35%|███▍      | 3655/10570 [00:10<00:19, 357.07it/s]#033[A
# #015 35%|███▍      | 3691/10570 [00:10<00:19, 357.90it/s]#033[A
# #015 35%|███▌      | 3727/10570 [00:10<00:19, 357.60it/s]#033[A
# #015 36%|███▌      | 3764/10570 [00:10<00:18, 358.64it/s]#033[A
# #015 36%|███▌      | 3800/10570 [00:10<00:19, 356.11it/s]#033[A
# #015 36%|███▋      | 3837/10570 [00:10<00:18, 358.06it/s]#033[A
# #015 37%|███▋      | 3874/10570 [00:11<00:18, 359.03it/s]#033[A
# #015 37%|███▋      | 3910/10570 [00:11<00:18, 359.25it/s]#033[A
# #015 37%|███▋      | 3946/10570 [00:11<00:18, 359.35it/s]#033[A
# #015 38%|███▊      | 3983/10570 [00:11<00:18, 361.73it/s]#033[A
# #015 38%|███▊      | 4020/10570 [00:11<00:18, 358.23it/s]#033[A
# #015 38%|███▊      | 4057/10570 [00:11<00:18, 359.44it/s]#033[A
# #015 39%|███▊      | 4094/10570 [00:11<00:17, 360.56it/s]#033[A
# #015 39%|███▉      | 4131/10570 [00:11<00:18, 341.45it/s]#033[A
# #015 39%|███▉      | 4166/10570 [00:11<00:22, 284.33it/s]#033[A
# #015 40%|███▉      | 4197/10570 [00:12<00:24, 260.22it/s]#033[A
# #015 40%|███▉      | 4225/10570 [00:12<00:24, 259.27it/s]#033[A
# #015 40%|████      | 4257/10570 [00:12<00:23, 273.73it/s]#033[A
# #015 41%|████      | 4286/10570 [00:12<00:30, 208.68it/s]#033[A
# #015 41%|████      | 4310/10570 [00:12<00:31, 200.19it/s]#033[A
# #015 41%|████      | 4346/10570 [00:12<00:26, 235.33it/s]#033[A
# #015 41%|████▏     | 4382/10570 [00:12<00:23, 264.71it/s]#033[A
# #015 42%|████▏     | 4417/10570 [00:12<00:21, 286.13it/s]#033[A
# #015 42%|████▏     | 4454/10570 [00:13<00:19, 306.98it/s]#033[A
# #015 42%|████▏     | 4492/10570 [00:13<00:18, 324.43it/s]#033[A
# #015 43%|████▎     | 4526/10570 [00:13<00:18, 321.68it/s]#033[A
# #015 43%|████▎     | 4561/10570 [00:13<00:18, 327.83it/s]#033[A
# #015 43%|████▎     | 4595/10570 [00:13<00:18, 328.86it/s]#033[A
# #015 44%|████▍     | 4629/10570 [00:13<00:18, 322.68it/s]#033[A
# #015 44%|████▍     | 4662/10570 [00:13<00:18, 312.25it/s]#033[A
# #015 44%|████▍     | 4697/10570 [00:13<00:18, 322.82it/s]#033[A
# #015 45%|████▍     | 4730/10570 [00:13<00:18, 324.03it/s]#033[A
# #015 45%|████▌     | 4763/10570 [00:13<00:18, 313.95it/s]#033[A
# #015 45%|████▌     | 4796/10570 [00:14<00:18, 317.94it/s]#033[A
# #015 46%|████▌     | 4833/10570 [00:14<00:17, 332.56it/s]#033[A
# #015 46%|████▌     | 4867/10570 [00:14<00:18, 314.74it/s]#033[A
# #015 46%|████▋     | 4903/10570 [00:14<00:17, 327.08it/s]#033[A
# #015 47%|████▋     | 4939/10570 [00:14<00:16, 334.00it/s]#033[A
# #015 47%|████▋     | 4973/10570 [00:14<00:16, 335.61it/s]#033[A
# #015 47%|████▋     | 5007/10570 [00:14<00:16, 333.76it/s]#033[A
# #015 48%|████▊     | 5042/10570 [00:14<00:16, 337.02it/s]#033[A
# #015 48%|████▊     | 5077/10570 [00:14<00:16, 340.31it/s]#033[A
# #015 48%|████▊     | 5113/10570 [00:15<00:15, 344.48it/s]#033[A
# #015 49%|████▊     | 5149/10570 [00:15<00:15, 348.10it/s]#033[A
# #015 49%|████▉     | 5185/10570 [00:15<00:15, 350.35it/s]#033[A
# #015 49%|████▉     | 5222/10570 [00:15<00:15, 353.60it/s]#033[A
# #015 50%|████▉     | 5258/10570 [00:15<00:15, 352.60it/s]#033[A
# #015 50%|█████     | 5295/10570 [00:15<00:14, 357.62it/s]#033[A
# #015 50%|█████     | 5332/10570 [00:15<00:14, 361.06it/s]#033[A
# #015 51%|█████     | 5369/10570 [00:15<00:14, 356.62it/s]#033[A
# #015 51%|█████     | 5405/10570 [00:15<00:14, 356.67it/s]#033[A
# #015 51%|█████▏    | 5441/10570 [00:15<00:14, 353.44it/s]#033[A
# #015 52%|█████▏    | 5477/10570 [00:16<00:15, 328.00it/s]#033[A
# #015 52%|█████▏    | 5511/10570 [00:16<00:15, 316.37it/s]#033[A
# #015 52%|█████▏    | 5545/10570 [00:16<00:15, 321.93it/s]#033[A
# #015 53%|█████▎    | 5579/10570 [00:16<00:15, 325.50it/s]#033[A
# #015 53%|█████▎    | 5614/10570 [00:16<00:14, 330.71it/s]#033[A
# #015 53%|█████▎    | 5648/10570 [00:16<00:14, 331.09it/s]#033[A
# #015 54%|█████▍    | 5682/10570 [00:16<00:15, 322.25it/s]#033[A
# #015 54%|█████▍    | 5719/10570 [00:16<00:14, 333.32it/s]#033[A
# #015 54%|█████▍    | 5753/10570 [00:16<00:14, 334.54it/s]#033[A
# #015 55%|█████▍    | 5787/10570 [00:17<00:14, 333.68it/s]#033[A
# #015 55%|█████▌    | 5821/10570 [00:17<00:14, 334.45it/s]#033[A
# #015 55%|█████▌    | 5856/10570 [00:17<00:14, 335.97it/s]#033[A
# #015 56%|█████▌    | 5892/10570 [00:17<00:13, 342.85it/s]#033[A
# #015 56%|█████▌    | 5927/10570 [00:17<00:13, 338.90it/s]#033[A
# #015 56%|█████▋    | 5963/10570 [00:17<00:13, 344.00it/s]#033[A
# #015 57%|█████▋    | 5998/10570 [00:17<00:13, 345.08it/s]#033[A
# #015 57%|█████▋    | 6033/10570 [00:17<00:13, 343.28it/s]#033[A
# #015 57%|█████▋    | 6068/10570 [00:17<00:13, 336.30it/s]#033[A
# #015 58%|█████▊    | 6102/10570 [00:17<00:13, 336.11it/s]#033[A
# #015 58%|█████▊    | 6139/10570 [00:18<00:12, 343.22it/s]#033[A
# #015 58%|█████▊    | 6175/10570 [00:18<00:12, 346.31it/s]#033[A
# #015 59%|█████▉    | 6210/10570 [00:18<00:12, 345.34it/s]#033[A
# #015 59%|█████▉    | 6245/10570 [00:18<00:13, 330.71it/s]#033[A
# #015 59%|█████▉    | 6280/10570 [00:18<00:12, 335.16it/s]#033[A
# #015 60%|█████▉    | 6317/10570 [00:18<00:12, 343.12it/s]#033[A
# #015 60%|██████    | 6352/10570 [00:18<00:12, 342.88it/s]#033[A
# #015 60%|██████    | 6387/10570 [00:18<00:12, 330.25it/s]#033[A
# #015 61%|██████    | 6421/10570 [00:18<00:12, 331.67it/s]#033[A
# #015 61%|██████    | 6458/10570 [00:18<00:12, 341.99it/s]#033[A
# #015 61%|██████▏   | 6494/10570 [00:19<00:11, 345.61it/s]#033[A
# #015 62%|██████▏   | 6530/10570 [00:19<00:11, 347.24it/s]#033[A
# #015 62%|██████▏   | 6566/10570 [00:19<00:11, 349.18it/s]#033[A
# #015 62%|██████▏   | 6601/10570 [00:19<00:11, 344.88it/s]#033[A
# #015 63%|██████▎   | 6638/10570 [00:19<00:11, 350.39it/s]#033[A
# #015 63%|██████▎   | 6674/10570 [00:19<00:11, 348.06it/s]#033[A
# #015 63%|██████▎   | 6709/10570 [00:19<00:11, 337.84it/s]#033[A
# #015 64%|██████▍   | 6744/10570 [00:19<00:11, 340.36it/s]#033[A
# #015 64%|██████▍   | 6779/10570 [00:19<00:11, 339.87it/s]#033[A
# #015 64%|██████▍   | 6814/10570 [00:20<00:11, 338.59it/s]#033[A
# #015 65%|██████▍   | 6848/10570 [00:20<00:11, 336.46it/s]#033[A
# #015 65%|██████▌   | 6882/10570 [00:20<00:10, 335.93it/s]#033[A
# #015 65%|██████▌   | 6917/10570 [00:20<00:10, 338.06it/s]#033[A
# #015 66%|██████▌   | 6954/10570 [00:20<00:10, 345.42it/s]#033[A
# #015 66%|██████▌   | 6991/10570 [00:20<00:10, 350.84it/s]#033[A
# #015 66%|██████▋   | 7028/10570 [00:20<00:10, 354.06it/s]#033[A
# #015 67%|██████▋   | 7064/10570 [00:20<00:09, 353.85it/s]#033[A
# #015 67%|██████▋   | 7100/10570 [00:20<00:09, 351.94it/s]#033[A
# #015 68%|██████▊   | 7136/10570 [00:20<00:09, 347.30it/s]#033[A
# #015 68%|██████▊   | 7172/10570 [00:21<00:09, 350.70it/s]#033[A
# #015 68%|██████▊   | 7208/10570 [00:21<00:09, 349.86it/s]#033[A
# #015 69%|██████▊   | 7244/10570 [00:21<00:09, 348.01it/s]#033[A
# #015 69%|██████▉   | 7279/10570 [00:21<00:09, 347.68it/s]#033[A
# #015 69%|██████▉   | 7316/10570 [00:21<00:09, 351.93it/s]#033[A
# #015 70%|██████▉   | 7352/10570 [00:21<00:10, 319.22it/s]#033[A
# #015 70%|██████▉   | 7387/10570 [00:21<00:09, 325.00it/s]#033[A
# #015 70%|███████   | 7423/10570 [00:21<00:09, 333.22it/s]#033[A
# #015 71%|███████   | 7458/10570 [00:21<00:09, 336.68it/s]#033[A
# #015 71%|███████   | 7492/10570 [00:22<00:09, 333.83it/s]#033[A
# #015 71%|███████   | 7528/10570 [00:22<00:08, 340.26it/s]#033[A
# #015 72%|███████▏  | 7563/10570 [00:22<00:08, 342.97it/s]#033[A
# #015 72%|███████▏  | 7600/10570 [00:22<00:08, 349.10it/s]#033[A
# #015 72%|███████▏  | 7636/10570 [00:22<00:08, 351.81it/s]#033[A
# #015 73%|███████▎  | 7672/10570 [00:22<00:08, 337.68it/s]#033[A
# #015 73%|███████▎  | 7709/10570 [00:22<00:08, 344.19it/s]#033[A
# #015 73%|███████▎  | 7744/10570 [00:22<00:08, 344.94it/s]#033[A
# #015 74%|███████▎  | 7779/10570 [00:22<00:08, 329.08it/s]#033[A
# #015 74%|███████▍  | 7813/10570 [00:22<00:08, 331.23it/s]#033[A
# #015 74%|███████▍  | 7848/10570 [00:23<00:08, 335.38it/s]#033[A
# #015 75%|███████▍  | 7884/10570 [00:23<00:07, 340.38it/s]#033[A
# #015 75%|███████▍  | 7921/10570 [00:23<00:07, 347.35it/s]#033[A
# #015 75%|███████▌  | 7957/10570 [00:23<00:07, 349.88it/s]#033[A
# #015 76%|███████▌  | 7993/10570 [00:23<00:07, 345.34it/s]#033[A
# #015 76%|███████▌  | 8028/10570 [00:23<00:07, 344.62it/s]#033[A
# #015 76%|███████▋  | 8063/10570 [00:23<00:07, 340.76it/s]#033[A
# #015 77%|███████▋  | 8100/10570 [00:23<00:07, 347.91it/s]#033[A
# #015 77%|███████▋  | 8135/10570 [00:23<00:07, 341.46it/s]#033[A
# #015 77%|███████▋  | 8170/10570 [00:23<00:07, 328.39it/s]#033[A
# #015 78%|███████▊  | 8203/10570 [00:24<00:07, 326.12it/s]#033[A
# #015 78%|███████▊  | 8236/10570 [00:24<00:07, 326.96it/s]#033[A
# #015 78%|███████▊  | 8269/10570 [00:24<00:07, 327.67it/s]#033[A
# #015 79%|███████▊  | 8302/10570 [00:24<00:07, 317.96it/s]#033[A
# #015 79%|███████▉  | 8336/10570 [00:24<00:06, 324.08it/s]#033[A
# #015 79%|███████▉  | 8372/10570 [00:24<00:06, 334.26it/s]#033[A
# #015 80%|███████▉  | 8408/10570 [00:24<00:06, 341.21it/s]#033[A
# #015 80%|███████▉  | 8445/10570 [00:24<00:06, 349.35it/s]#033[A
# #015 80%|████████  | 8482/10570 [00:24<00:05, 354.01it/s]#033[A
# #015 81%|████████  | 8518/10570 [00:25<00:05, 352.43it/s]#033[A
# #015 81%|████████  | 8554/10570 [00:25<00:05, 353.90it/s]#033[A
# #015 81%|████████▏ | 8590/10570 [00:25<00:05, 351.02it/s]#033[A
# #015 82%|████████▏ | 8627/10570 [00:25<00:05, 354.06it/s]#033[A
# #015 82%|████████▏ | 8663/10570 [00:25<00:05, 350.08it/s]#033[A
# #015 82%|████████▏ | 8700/10570 [00:25<00:05, 355.24it/s]#033[A
# #015 83%|████████▎ | 8736/10570 [00:25<00:05, 349.51it/s]#033[A
# #015 83%|████████▎ | 8771/10570 [00:25<00:05, 346.64it/s]#033[A
# #015 83%|████████▎ | 8806/10570 [00:25<00:05, 345.03it/s]#033[A
# #015 84%|████████▎ | 8841/10570 [00:25<00:05, 343.55it/s]#033[A
# #015 84%|████████▍ | 8877/10570 [00:26<00:04, 346.09it/s]#033[A
# #015 84%|████████▍ | 8912/10570 [00:26<00:04, 346.53it/s]#033[A
# #015 85%|████████▍ | 8948/10570 [00:26<00:04, 349.20it/s]#033[A
# #015 85%|████████▍ | 8984/10570 [00:26<00:04, 350.45it/s]#033[A
# #015 85%|████████▌ | 9020/10570 [00:26<00:04, 352.46it/s]#033[A
# #015 86%|████████▌ | 9056/10570 [00:26<00:04, 350.11it/s]#033[A
# #015 86%|████████▌ | 9092/10570 [00:26<00:04, 349.99it/s]#033[A
# #015 86%|████████▋ | 9128/10570 [00:26<00:04, 350.36it/s]#033[A
# #015 87%|████████▋ | 9164/10570 [00:26<00:04, 349.12it/s]#033[A
# #015 87%|████████▋ | 9200/10570 [00:26<00:03, 351.04it/s]#033[A
# #015 87%|████████▋ | 9236/10570 [00:27<00:03, 348.82it/s]#033[A
# #015 88%|████████▊ | 9273/10570 [00:27<00:03, 352.41it/s]#033[A
# #015 88%|████████▊ | 9309/10570 [00:27<00:03, 351.99it/s]#033[A
# #015 88%|████████▊ | 9345/10570 [00:27<00:03, 349.97it/s]#033[A
# #015 89%|████████▉ | 9381/10570 [00:27<00:03, 351.64it/s]#033[A
# #015 89%|████████▉ | 9417/10570 [00:27<00:03, 351.71it/s]#033[A
# #015 89%|████████▉ | 9454/10570 [00:27<00:03, 354.69it/s]#033[A
# #015 90%|████████▉ | 9490/10570 [00:27<00:03, 355.38it/s]#033[A
# #015 90%|█████████ | 9526/10570 [00:27<00:02, 356.30it/s]#033[A
# #015 90%|█████████ | 9563/10570 [00:27<00:02, 359.24it/s]#033[A
# #015 91%|█████████ | 9599/10570 [00:28<00:02, 349.11it/s]#033[A
# #015 91%|█████████ | 9636/10570 [00:28<00:02, 353.00it/s]#033[A
# #015 92%|█████████▏| 9673/10570 [00:28<00:02, 356.13it/s]#033[A
# #015 92%|█████████▏| 9710/10570 [00:28<00:02, 359.22it/s]#033[A
# #015 92%|█████████▏| 9747/10570 [00:28<00:02, 360.61it/s]#033[A
# #015 93%|█████████▎| 9784/10570 [00:28<00:02, 360.40it/s]#033[A
# #015 93%|█████████▎| 9821/10570 [00:28<00:02, 360.47it/s]#033[A
# #015 93%|█████████▎| 9858/10570 [00:28<00:02, 352.49it/s]#033[A
# #015 94%|█████████▎| 9894/10570 [00:28<00:01, 350.79it/s]#033[A
# #015 94%|█████████▍| 9930/10570 [00:29<00:01, 346.15it/s]#033[A
# #015 94%|█████████▍| 9965/10570 [00:29<00:01, 339.39it/s]#033[A
# #015 95%|█████████▍| 9999/10570 [00:29<00:01, 338.55it/s]#033[A
# #015 95%|█████████▍| 10034/10570 [00:29<00:01, 341.28it/s]#033[A
# #015 95%|█████████▌| 10070/10570 [00:29<00:01, 345.65it/s]#033[A
# #015 96%|█████████▌| 10106/10570 [00:29<00:01, 349.81it/s]#033[A
# #015 96%|█████████▌| 10143/10570 [00:29<00:01, 353.82it/s]#033[A
# #015 96%|█████████▋| 10179/10570 [00:29<00:01, 343.58it/s]#033[A
# #015 97%|█████████▋| 10215/10570 [00:29<00:01, 348.16it/s]#033[A
# #015 97%|█████████▋| 10252/10570 [00:29<00:00, 351.88it/s]#033[A
# #015 97%|█████████▋| 10288/10570 [00:30<00:00, 349.35it/s]#033[A
# #015 98%|█████████▊| 10324/10570 [00:30<00:00, 350.62it/s]#033[A
# #015 98%|█████████▊| 10360/10570 [00:30<00:00, 351.43it/s]#033[A
# #015 98%|█████████▊| 10396/10570 [00:30<00:00, 347.80it/s]#033[A
# #015 99%|█████████▊| 10432/10570 [00:30<00:00, 349.05it/s]#033[A
# #015 99%|█████████▉| 10467/10570 [00:30<00:00, 345.01it/s]#033[A
# #015 99%|█████████▉| 10503/10570 [00:30<00:00, 347.12it/s]#033[A
# #015100%|█████████▉| 10540/10570 [00:30<00:00, 352.04it/s]#033[A#015100%|██████████| 10570/10570 [00:30<00:00, 342.37it/s]
# #015100%|██████████| 2696/2696 [03:16<00:00, 13.73it/s]
# [INFO|modelcard.py:460] 2022-06-15 15:40:44,705 >> Dropping the following result as it does not have all the necessary fields:
# {'task': {'name': 'Question Answering', 'type': 'question-answering'}, 'dataset': {'name': 'squad', 'type': 'squad', 'args': 'plain_text'}}
#
# 2022-06-15 15:45:28 Completed - Training job completed
# Training seconds: 2014
# Billable seconds: 2014

# %%
huggingface_estimator.latest_job_profiler_artifacts_path()
# Out:
# 's3://sagemaker-us-west-2-976939723775/torch-hf-gpu-2022-06-06-17-01/profiler-output'

# %%
predictor = huggingface_estimator.deploy(1,"ml.m4.2xlarge")

# %%
data = {
"inputs": {
	#"question": "What is used for inference?",
    "question": "What does Philipp live?",
	"context": "My Name is Philipp and I live in Nuremberg. This model is used with sagemaker for inference."
	}
}
predictor.predict(data)

# %% [markdown]
# ### Optional cleanup
# When you're done with the endpoint, you should clean it up.
#
# All the training jobs, models and endpoints we created can be viewed through the SageMaker console of your AWS account.

# %%
predictor.delete_endpoint()
